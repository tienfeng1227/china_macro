# %% [markdown]
# # 1. Library 불러오기

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# # 2. 오프라인에서 Plolty 활용하기

# %%
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)
import plotly.io as pio
pio.renderers.default = "notebook_connected"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 3. 데이터 가공

# %% [markdown]
# ### (1) 중국 생산계정 GDP

# %%
df_gdp_pro = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = 'GDP생산')

# %%
df_gdp_pro = df_gdp_pro.iloc[24:]
df_gdp_pro = df_gdp_pro.iloc[:, 0:7]

# %%
df_gdp_pro = df_gdp_pro.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_gdp_pro = df_gdp_pro.rename(columns = {'CN: GDP Index: YoY': 'GDP_YoY'})
df_gdp_pro = df_gdp_pro.rename(columns = {'CN: GDP Index: YoY: Primary Industry': 'GDP_PI_YoY'})
df_gdp_pro = df_gdp_pro.rename(columns = {'CN: GDP Index: YoY: Secondary Industry(SI)': 'GDP_SI_YoY'})
df_gdp_pro = df_gdp_pro.rename(columns = {'CN: GDP Index: YoY: SI: Industry: Manufacturing': 'GDP_SI_MN_YoY'})
df_gdp_pro = df_gdp_pro.rename(columns = {'CN: GDP Index: YoY: SI: Construction': 'GDP_SI_CS_YoY'})
df_gdp_pro = df_gdp_pro.rename(columns = {'CN: GDP Index: YoY: Tertiary Industry(TI)': 'GDP_TI_YoY'})

# %%
df_gdp_pro['GDP_YoY_New'] = df_gdp_pro['GDP_YoY'] - 100
df_gdp_pro['GDP_PI_YoY_New'] = df_gdp_pro['GDP_PI_YoY'] - 100
df_gdp_pro['GDP_SI_YoY_New'] = df_gdp_pro['GDP_SI_YoY'] - 100
df_gdp_pro['GDP_SI_MN_YoY_New'] = df_gdp_pro['GDP_SI_MN_YoY'] - 100
df_gdp_pro['GDP_SI_CS_YoY_New'] = df_gdp_pro['GDP_SI_CS_YoY'] - 100
df_gdp_pro['GDP_TI_YoY_New'] = df_gdp_pro['GDP_TI_YoY'] - 100
df_gdp_pro.tail()
# Out:
#                     DATE GDP_YoY GDP_PI_YoY GDP_SI_YoY GDP_SI_MN_YoY  \
# 139  2020-12-01 00:00:00   106.4      104.3      106.7         107.4
# 140  2021-03-01 00:00:00   118.3      108.1      124.4         126.8
# 141  2021-06-01 00:00:00   107.9      107.6      107.5         109.2
# 142  2021-09-01 00:00:00   104.9      107.1      103.6         104.6
# 143  2021-12-01 00:00:00     104      106.4      102.5         103.1
#
#     GDP_SI_CS_YoY GDP_TI_YoY GDP_YoY_New GDP_PI_YoY_New GDP_SI_YoY_New  \
# 139         105.8      106.6         6.4            4.3            6.7
# 140         122.8      115.6        18.3            8.1           24.4
# 141         101.8      108.3         7.9            7.6            7.5
# 142          98.2      105.4         4.9            7.1            3.6
# 143          97.9      104.6           4            6.4            2.5
#
#     GDP_SI_MN_YoY_New GDP_SI_CS_YoY_New GDP_TI_YoY_New
# 139               7.4               5.8            6.6
# 140              26.8              22.8           15.6
# 141               9.2               1.8            8.3
# 142               4.6              -1.8            5.4
# 143               3.1              -2.1            4.6

# %%
df_gdp_pro['new_Date'] = pd.to_datetime(df_gdp_pro['DATE'])
df_gdp_pro.set_index('new_Date',inplace=True)
df_gdp_pro.head()
# Out:
#                            DATE GDP_YoY GDP_PI_YoY GDP_SI_YoY GDP_SI_MN_YoY  \
# new_Date
# 1992-03-01  1992-03-01 00:00:00   113.6      108.8      118.3           NaN
# 1992-06-01  1992-06-01 00:00:00   114.1      106.1      120.1           NaN
# 1992-09-01  1992-09-01 00:00:00   114.6      103.4      121.1           NaN
# 1992-12-01  1992-12-01 00:00:00   114.6      103.5      124.3           NaN
# 1993-03-01  1993-03-01 00:00:00   115.3        105      120.9           NaN
#
#            GDP_SI_CS_YoY GDP_TI_YoY GDP_YoY_New GDP_PI_YoY_New GDP_SI_YoY_New  \
# new_Date
# 1992-03-01         118.1      109.7        13.6            8.8           18.3
# 1992-06-01         120.6        112        14.1            6.1           20.1
# 1992-09-01         122.1      115.6        14.6            3.4           21.1
# 1992-12-01         121.6      113.3        14.6            3.5           24.3
# 1993-03-01         122.9      111.9        15.3              5           20.9
#
#            GDP_SI_MN_YoY_New GDP_SI_CS_YoY_New GDP_TI_YoY_New
# new_Date
# 1992-03-01               NaN              18.1            9.7
# 1992-06-01               NaN              20.6             12
# 1992-09-01               NaN              22.1           15.6
# 1992-12-01               NaN              21.6           13.3
# 1993-03-01               NaN              22.9           11.9

# %%
df_gdp_pro_new = df_gdp_pro.loc["2015-01-01":]
df_gdp_pro_new.head()
# Out:
#                            DATE GDP_YoY GDP_PI_YoY GDP_SI_YoY GDP_SI_MN_YoY  \
# new_Date
# 2015-03-01  2015-03-01 00:00:00   107.1      103.1      106.2         106.3
# 2015-06-01  2015-06-01 00:00:00   107.1      103.7      105.9         106.3
# 2015-09-01  2015-09-01 00:00:00     107      104.1      105.7           106
# 2015-12-01  2015-12-01 00:00:00   106.9      104.1        106         106.3
# 2016-03-01  2016-03-01 00:00:00   106.9      102.9      105.8         105.5
#
#            GDP_SI_CS_YoY GDP_TI_YoY GDP_YoY_New GDP_PI_YoY_New GDP_SI_YoY_New  \
# new_Date
# 2015-03-01         109.2      108.4         7.1            3.1            6.2
# 2015-06-01         106.4        109         7.1            3.7            5.9
# 2015-09-01         106.4        109           7            4.1            5.7
# 2015-12-01         107.9      108.8         6.9            4.1              6
# 2016-03-01         108.9        108         6.9            2.9            5.8
#
#            GDP_SI_MN_YoY_New GDP_SI_CS_YoY_New GDP_TI_YoY_New
# new_Date
# 2015-03-01               6.3               9.2            8.4
# 2015-06-01               6.3               6.4              9
# 2015-09-01                 6               6.4              9
# 2015-12-01               6.3               7.9            8.8
# 2016-03-01               5.5               8.9              8

# %% [markdown]
# ### (2) 중국 지출계정 GDP

# %%
df_gdp_exp = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = 'GDP기여')

# %%
df_gdp_exp = df_gdp_exp.iloc[23:]
df_gdp_exp = df_gdp_exp.iloc[:, 0:7]

# %%
df_gdp_exp = df_gdp_exp.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_gdp_exp = df_gdp_exp.rename(columns = {'CN: Share to GDP Growth: Final Consumption Expenditure': 'GDP_SH_FCE'})
df_gdp_exp = df_gdp_exp.rename(columns = {'CN: Share to GDP Growth: Gross Capital Formation': 'GDP_SH_GCF'})
df_gdp_exp = df_gdp_exp.rename(columns = {'CN: Share to GDP Growth: Net Export of Goods and Service': 'GDP_SH_NEX'})
df_gdp_exp = df_gdp_exp.rename(columns = {'CN: Contribution to GDP Growth: Final Consumption Expenditure': 'GDP_CO_FCE'})
df_gdp_exp = df_gdp_exp.rename(columns = {'CN: Contribution to GDP Growth: Gross Capital Formation': 'GDP_CO_GCF'})
df_gdp_exp = df_gdp_exp.rename(columns = {'CN: Contribution to GDP Growth: Net Export of Goods and Service': 'GDP_CO_NEX'})
df_gdp_exp.tail()
# Out:
#                    DATE GDP_SH_FCE GDP_SH_GCF GDP_SH_NEX GDP_CO_FCE  \
# 46  2020-12-01 00:00:00       44.8       31.5       23.7     2.8672
# 47  2021-03-01 00:00:00       50.7         24       25.3     9.2781
# 48  2021-06-01 00:00:00       74.1       12.8       13.1     5.8539
# 49  2021-09-01 00:00:00       77.5        7.8       14.7     3.7975
# 50  2021-12-01 00:00:00       85.3      -11.6       26.4      3.412
#
#    GDP_CO_GCF GDP_CO_NEX
# 46      2.016     1.5168
# 47      4.392     4.6299
# 48     1.0112     1.0349
# 49     0.3822     0.7203
# 50     -0.464      1.056

# %%
df_gdp_exp['new_Date'] = pd.to_datetime(df_gdp_exp['DATE'])
df_gdp_exp.set_index('new_Date',inplace=True)
df_gdp_exp.head()
# Out:
#                            DATE GDP_SH_FCE GDP_SH_GCF GDP_SH_NEX GDP_CO_FCE  \
# new_Date
# 2015-03-01  2015-03-01 00:00:00       64.1       16.7       19.2      4.487
# 2015-06-01  2015-06-01 00:00:00       60.6         47       -7.6      4.242
# 2015-09-01  2015-09-01 00:00:00       51.3       59.1      -10.4     3.5397
# 2015-12-01  2015-12-01 00:00:00       63.5         39       -2.5      4.318
# 2016-03-01  2016-03-01 00:00:00       78.1       38.3      -16.4     5.3889
#
#            GDP_CO_GCF GDP_CO_NEX
# new_Date
# 2015-03-01      1.169      1.344
# 2015-06-01       3.29     -0.532
# 2015-09-01     4.0779    -0.7176
# 2015-12-01      2.652      -0.17
# 2016-03-01     2.6427    -1.1316

# %%
df_gdp_exp_new = df_gdp_exp.loc["2015-01-01":]
df_gdp_exp_new.head()
# Out:
#                            DATE GDP_SH_FCE GDP_SH_GCF GDP_SH_NEX GDP_CO_FCE  \
# new_Date
# 2015-03-01  2015-03-01 00:00:00       64.1       16.7       19.2      4.487
# 2015-06-01  2015-06-01 00:00:00       60.6         47       -7.6      4.242
# 2015-09-01  2015-09-01 00:00:00       51.3       59.1      -10.4     3.5397
# 2015-12-01  2015-12-01 00:00:00       63.5         39       -2.5      4.318
# 2016-03-01  2016-03-01 00:00:00       78.1       38.3      -16.4     5.3889
#
#            GDP_CO_GCF GDP_CO_NEX
# new_Date
# 2015-03-01      1.169      1.344
# 2015-06-01       3.29     -0.532
# 2015-09-01     4.0779    -0.7176
# 2015-12-01      2.652      -0.17
# 2016-03-01     2.6427    -1.1316

# %% [markdown]
# ### (3) 중국 물가지수

# %%
df_pi = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = '물가')

# %%
df_pi = df_pi.iloc[23:]
df_pi = df_pi.iloc[:, 0:6]

# %%
df_pi = df_pi.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_pi = df_pi.rename(columns = {'CN: Consumer Price Index': 'CPI'})
df_pi = df_pi.rename(columns = {'CN: CPI: Core (excl. Food & Energy)': 'CCPI'})
df_pi = df_pi.rename(columns = {'CN: Producer Price Index(PPI)': 'PPI'})
df_pi = df_pi.rename(columns = {'CN: Producer Price Index: Producer Goods': 'PPPI'})
df_pi = df_pi.rename(columns = {'CN: Producer Price Index: Consumer Goods': 'CPPI'})

# %%
df_pi['CPI_New'] = df_pi['CPI'] - 100
df_pi['CCPI_New'] = df_pi['CCPI'] - 100
df_pi['PPI_New'] = df_pi['PPI'] - 100
df_pi['PPPI_New'] = df_pi['PPPI'] - 100
df_pi['CPPI_New'] = df_pi['CPPI'] - 100
df_pi.tail()
# Out:
#                     DATE    CPI   CCPI    PPI   PPPI   CPPI CPI_New CCPI_New  \
# 464  2021-10-01 00:00:00  101.5  101.3  113.5  117.9  100.6     1.5      1.3
# 465  2021-11-01 00:00:00  102.3  101.2  112.9    117    101     2.3      1.2
# 466  2021-12-01 00:00:00  101.5  101.2  110.3  113.4    101     1.5      1.2
# 467  2022-01-01 00:00:00  100.9  101.2  109.1  111.8  100.8     0.9      1.2
# 468  2022-02-01 00:00:00  100.9  101.1  108.8  111.4  100.9     0.9      1.1
#
#     PPI_New PPPI_New CPPI_New
# 464    13.5     17.9      0.6
# 465    12.9       17        1
# 466    10.3     13.4        1
# 467     9.1     11.8      0.8
# 468     8.8     11.4      0.9

# %%
df_pi['new_Date'] = pd.to_datetime(df_pi['DATE'])
df_pi.set_index('new_Date',inplace=True)
df_pi.head()
# Out:
#                            DATE    CPI CCPI  PPI PPPI CPPI CPI_New CCPI_New  \
# new_Date
# 1985-01-01  1985-01-01 00:00:00  105.5  NaN  NaN  NaN  NaN     5.5      NaN
# 1985-02-01  1985-02-01 00:00:00  106.5  NaN  NaN  NaN  NaN     6.5      NaN
# 1985-03-01  1985-03-01 00:00:00    107  NaN  NaN  NaN  NaN       7      NaN
# 1985-04-01  1985-04-01 00:00:00  107.8  NaN  NaN  NaN  NaN     7.8      NaN
# 1985-05-01  1985-05-01 00:00:00  109.9  NaN  NaN  NaN  NaN     9.9      NaN
#
#            PPI_New PPPI_New CPPI_New
# new_Date
# 1985-01-01     NaN      NaN      NaN
# 1985-02-01     NaN      NaN      NaN
# 1985-03-01     NaN      NaN      NaN
# 1985-04-01     NaN      NaN      NaN
# 1985-05-01     NaN      NaN      NaN

# %%
df_pi_new = df_pi.loc["2017-01-01":]
df_pi_new.head()
# Out:
#                            DATE    CPI   CCPI    PPI   PPPI   CPPI CPI_New  \
# new_Date
# 2017-01-01  2017-01-01 00:00:00  102.5  102.2  106.9  109.1  100.8     2.5
# 2017-02-01  2017-02-01 00:00:00  100.8  101.8  107.8  110.4  100.8     0.8
# 2017-03-01  2017-03-01 00:00:00  100.9    102  107.6  110.1  100.7     0.9
# 2017-04-01  2017-04-01 00:00:00  101.2  102.1  106.4  108.4  100.7     1.2
# 2017-05-01  2017-05-01 00:00:00  101.5  102.1  105.5  107.3  100.6     1.5
#
#            CCPI_New PPI_New PPPI_New CPPI_New
# new_Date
# 2017-01-01      2.2     6.9      9.1      0.8
# 2017-02-01      1.8     7.8     10.4      0.8
# 2017-03-01        2     7.6     10.1      0.7
# 2017-04-01      2.1     6.4      8.4      0.7
# 2017-05-01      2.1     5.5      7.3      0.6

# %% [markdown]
# ### (4) 중국 통화량

# %%
df_ac = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = '통화') # amount of currency

# %%
df_ac = df_ac.iloc[23:]
df_ac = df_ac.iloc[:, 0:4]

# %%
df_ac = df_ac.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_ac = df_ac.rename(columns = {'CN: Money Supply M0: YoY': 'M0'})
df_ac = df_ac.rename(columns = {'CN: Money Supply M1: YoY': 'M1'})
df_ac = df_ac.rename(columns = {'CN: Money Supply M2: YoY': 'M2'})
df_ac.tail()
# Out:
#                     DATE    M0   M1   M2
# 318  2021-10-01 00:00:00   6.2  2.8  8.7
# 319  2021-11-01 00:00:00   7.2    3  8.5
# 320  2021-12-01 00:00:00   7.7  3.5    9
# 321  2022-01-01 00:00:00  18.5 -1.9  9.8
# 322  2022-02-01 00:00:00   5.8  4.7  9.2

# %% [markdown]
# ### (5) 중국 사회융자총액

# %%
df_af = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = '융자')

# %%
df_af = df_af.iloc[23:]
df_af = df_af.iloc[:, 0:10]

# %%
df_af = df_af.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing': 'TAF'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing: Loan in Local Currency': 'LC_AF'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing: Loan in Foreign Currency': 'FC_AF'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing: Entrusted Loan': 'EL_AF'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing: Trust Loan': 'TL_AF'})
df_af = df_af.rename(columns = {"CN: Aggregate Financing: Banker's Acceptance Bill": 'BAC_AF'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing: Corporate Bond Financing': 'CB_AF'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing: Non Financial Enterprise Equity Financing': 'EF_AF'})
df_af = df_af.rename(columns = {'CN: Aggregate Financing: Government Bond': 'GB_AF'})

# %%
df_af['SBS_AF'] = df_af['EL_AF'] + df_af['TL_AF'] + df_af['BAC_AF'] + df_af['CB_AF'] + df_af['EF_AF']
df_af['LC_AF_YoY'] = df_af['LC_AF'].pct_change(12) * 100
df_af['SBS_AF_YoY'] = df_af['SBS_AF'].pct_change(12) * 100
df_af.tail()
# Out:
#                     DATE     TAF   LC_AF FC_AF  EL_AF TL_AF BAC_AF  CB_AF  \
# 120  2021-10-01 00:00:00  309450  189200  2310  10910  5030   3190  29360
# 121  2021-11-01 00:00:00  311900  190500  2300  10920  4810   3160  29720
# 122  2021-12-01 00:00:00  314130  191540  2230  10870  4360   3010  29930
# 123  2022-01-01 00:00:00  320050  195710  2260  10930  4280   3480  30450
# 124  2022-02-01 00:00:00  321120  196620  2290  10920  4200   3060  30760
#
#     EF_AF  GB_AF SBS_AF  LC_AF_YoY  SBS_AF_YoY
# 120  9150  51080  57640  12.005683    0.383142
# 121  9280  51900  57890  11.762980    0.888811
# 122  9480  53060  57650  11.620047    1.532230
# 123  9630  53670  58770  11.572886    2.190923
# 124  9660  53940  58600  11.235574    1.665510

# %%
df_af['new_Date'] = pd.to_datetime(df_af['DATE'])
df_af.set_index('new_Date',inplace=True)
df_af.head()
# Out:
#                            DATE      TAF         LC_AF       FC_AF  \
# new_Date
# 2002-12-01  2002-12-01 00:00:00  14853.2  11820.825036  523.224375
# 2003-12-01  2003-12-01 00:00:00  18165.5  14350.481593  662.402058
# 2004-12-01  2004-12-01 00:00:00  20414.3  16402.600461  773.685604
# 2005-12-01  2005-12-01 00:00:00  22426.5  18584.146323   858.79102
# 2006-12-01  2006-12-01 00:00:00    26450  21613.362173  936.082212
#
#                   EL_AF       TL_AF      BAC_AF       CB_AF       EF_AF GB_AF  \
# new_Date
# 2002-12-01   451.511139         NaN  159.855796   60.869079  677.262236   NaN
# 2003-12-01   511.562121         NaN  361.274099  141.764085  731.443215   NaN
# 2004-12-01   826.684388         NaN  332.372171  147.434649  793.615888   NaN
# 2005-12-01   924.233145         NaN  334.698776  337.772781  826.947755   NaN
# 2006-12-01  1109.079774  202.806669  484.978527  569.822681  930.316225   NaN
#
#                  SBS_AF  LC_AF_YoY  SBS_AF_YoY
# new_Date
# 2002-12-01          NaN        NaN         NaN
# 2003-12-01          NaN        NaN         NaN
# 2004-12-01          NaN        NaN         NaN
# 2005-12-01          NaN        NaN         NaN
# 2006-12-01  3297.003875        NaN         NaN

# %%
df_af_new = df_af.loc["2017-01-01":]
df_af_new.head()
# Out:
#                            DATE            TAF          LC_AF        FC_AF  \
# new_Date
# 2017-01-01  2017-01-01 00:00:00  184143.349415  107499.342628  2612.947279
# 2017-02-01  2017-02-01 00:00:00  185247.506336  108531.074453  2655.981182
# 2017-03-01  2017-03-01 00:00:00  187787.965693  109689.680081  2694.179881
# 2017-04-01  2017-04-01 00:00:00  189713.923553  110770.248887  2663.457024
# 2017-05-01  2017-05-01 00:00:00   191456.74618  111948.284782  2642.037647
#
#                    EL_AF        TL_AF       BAC_AF         CB_AF        EF_AF  \
# new_Date
# 2017-01-01   13509.70072  6525.805867  4515.229436  18122.467671  5894.786902
# 2017-02-01  13627.828273  6631.987411  4343.370882  18057.117986     5951.829
# 2017-03-01  13832.119739   6943.23798  4582.395319  18109.635752     6031.838
# 2017-04-01  13827.277734  7090.516325  4616.846942  18178.150716     6108.745
# 2017-05-01  13799.909865  7271.760044  4492.345418  17959.745418     6154.529
#
#                    GB_AF        SBS_AF  LC_AF_YoY  SBS_AF_YoY
# new_Date
# 2017-01-01   22639.97989  48567.990597  12.813966   14.406809
# 2017-02-01  22620.910755  48612.133551  12.936053   13.933491
# 2017-03-01  22943.909062  49499.226789  12.597929   13.465416
# 2017-04-01  23537.802316  49821.536716  13.052388   13.254807
# 2017-05-01  24188.264738  49678.289745  13.171933   13.426631

# %% [markdown]
# ### (6) 중국 산업생산

# %%
df_ip = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = '산업생산')

# %%
df_ip = df_ip.iloc[25:]
df_ip = df_ip.iloc[:, 0:3]

# %%
df_ip = df_ip.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_ip = df_ip.rename(columns = {'CN: Value Added of Industry: YoY: ytd(Real)': 'IP_YTD_YoY'})
df_ip = df_ip.rename(columns = {'CN: Value Added of Industry: YoY(Real)': 'IP_YoY'})

# %%
df_ip['IP_New'] = np.where(pd.notnull(df_ip['IP_YoY']) == True, df_ip['IP_YoY'], df_ip['IP_YTD_YoY'])

# %%
df_ip = df_ip.set_index("DATE", inplace=True)
index_ip = pd.date_range("2013-01-01", "2022-01-01", freq="YS")
empty_ip = pd.DataFrame(index=index_ip, columns=["data"])
new_data_ip = pd.concat([df_ip, empty_ip], axis = 1, sort = False)
# Out:
#            IP_YTD_YoY IP_YoY IP_New data
# 2021-10-01       10.9    3.5    3.5  NaN
# 2021-11-01       10.1    3.8    3.8  NaN
# 2021-12-01        9.6    4.3    4.3  NaN
# 2022-01-01        NaN    NaN    NaN  NaN
# 2022-02-01        7.5    NaN    7.5  NaN

# %%
new_data_ip = new_data_ip.fillna(method='bfill')
# Out:
#             IP_YTD_YoY  IP_YoY  IP_New  data
# 2021-10-01        10.9     3.5     3.5   NaN
# 2021-11-01        10.1     3.8     3.8   NaN
# 2021-12-01         9.6     4.3     4.3   NaN
# 2022-01-01         7.5     NaN     7.5   NaN
# 2022-02-01         7.5     NaN     7.5   NaN

# %%
# new_data_ip = new_data_ip.loc["2017-01-01":]

# %% [markdown]
# ### (7) 중국 고정자산투자

# %%
df_fa = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = 'FAI')

# %%
df_fa = df_fa.iloc[23:]
df_fa = df_fa.iloc[:, 0:17]

# %%
df_fa = df_fa.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_fa = df_fa.rename(columns = {'CN: Fixed Asset Investment: ytd': 'FA'})
df_fa = df_fa.rename(columns = {'CN: Fixed Asset Inv: YoY: ytd(Real)': 'FA_YoY_real'})
df_fa = df_fa.rename(columns = {'CN: Fixed Asset Inv: YoY: ytd': 'FA_YoY'})
df_fa = df_fa.rename(columns = {'CN: Fixed Asset Inv: YoY: ytd: State Owned & Holding Enterprise': 'FA_SOE_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: Private: YoY: ytd': 'FA_PRV_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: Construction and Installation': 'FA_CON_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: Equipment Purchase': 'FA_EQU_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: Others': 'FA_OTH_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: Investment Amount: Project Newly Started': 'FA_New_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: ytd: Primary Industry': 'FA_PI'})
df_fa = df_fa.rename(columns = {'CN: FAI: ytd: Secondary Industry (SI)': 'FA_SI'})
df_fa = df_fa.rename(columns = {'CN: FAI: ytd: Tertiary Industry': 'FA_TI'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: Primary Industry': 'FA_PI_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: Secondary Industry (SI)': 'FA_SI_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: SI: Construction': 'FA_SI_CON_YoY'})
df_fa = df_fa.rename(columns = {'CN: FAI: YoY: ytd: Tertiary Industry': 'FA_TI_YoY'})

# %%
df_fa['new_Date'] = pd.to_datetime(df_fa['DATE'])
df_fa.set_index('new_Date',inplace=True)

# %%
df_fa_new = df_fa.loc["2017-01-01":]
df_fa_new.head()
# Out:
#                            DATE        FA FA_YoY_real FA_YoY FA_SOE_YoY  \
# new_Date
# 2017-01-01  2017-01-01 00:00:00   4137789         NaN    8.9       14.4
# 2017-02-01  2017-02-01 00:00:00   4137789         NaN    8.9       14.4
# 2017-03-01  2017-03-01 00:00:00   9377706         NaN    9.2       13.6
# 2017-04-01  2017-04-01 00:00:00  14432684         NaN    8.9       13.8
# 2017-05-01  2017-05-01 00:00:00  20371827         NaN    8.6       12.6
#
#            FA_PRV_YoY FA_CON_YoY FA_EQU_YoY FA_OTH_YoY FA_New_YoY   FA_PI  \
# new_Date
# 2017-01-01        6.7        9.9       10.5        0.8       -8.3   88584
# 2017-02-01        6.7        9.9       10.5        0.8       -8.3   88584
# 2017-03-01        7.7       10.1        9.9        3.8       -6.5  233451
# 2017-04-01        6.9        9.8        7.2        5.5       -5.9  393075
# 2017-05-01        6.8        9.2        7.7        5.7       -5.6  593823
#
#               FA_SI     FA_TI FA_PI_YoY FA_SI_YoY FA_SI_CON_YoY FA_TI_YoY
# new_Date
# 2017-01-01  1449556   2599649      19.1       2.9         -37.3      12.2
# 2017-02-01  1449556   2599649      19.1       2.9         -37.3      12.2
# 2017-03-01  3509359   5634896      19.8       4.2         -27.9      12.2
# 2017-04-01  5459558   8580051      19.1       3.5         -14.7      12.1
# 2017-05-01  7757206  12020798      16.9       3.6         -20.3      11.6

# %% [markdown]
# ### (8) 중국 제조업 PMI

# %%
df_mpmi = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = 'MPMI (1)')

# %%
df_mpmi = df_mpmi.iloc[13:]
df_mpmi = df_mpmi.iloc[:, 0:16]

# %%
df_mpmi = df_mpmi.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_mpmi = df_mpmi.rename(columns = {"CN: Purchasing Managers' Index: Mfg": 'MPMI'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Production": 'MPMI_PRO'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: New Order": 'MPMI_NO'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: New Export Order": 'MPMI_NEO'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Backlog Order": 'MPMI_BO'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Finished Goods Inventory": 'MPMI_FGI'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Purchases": 'MPMI_PUR'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Import": 'MPMI_IMP'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Purchasing Price Index": 'MPMI_PUI'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Producer Price Index": 'MPMI_PPI'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Raw Material Inventory": 'MPMI_RMI'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Employment": 'MPMI_EMP'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Suppliers' Delivery Time": 'MPMI_SDT'})
df_mpmi = df_mpmi.rename(columns = {"CN: PMI: Mfg: Production and Business Expectation": 'MPMI_BEP'})
df_mpmi = df_mpmi.rename(columns = {"기준": 'MPMI_50'})

# %%
df_mpmi['new_Date'] = pd.to_datetime(df_mpmi['DATE'])
df_mpmi.set_index('new_Date',inplace=True)
df_mpmi.head()
# Out:
#                            DATE  MPMI MPMI_PRO MPMI_NO MPMI_NEO MPMI_BO  \
# new_Date
# 2005-01-01  2005-01-01 00:00:00  54.7     57.6    60.7     58.3    46.6
# 2005-02-01  2005-02-01 00:00:00  54.5     55.6    61.5     59.9    49.8
# 2005-03-01  2005-03-01 00:00:00  57.9     65.2    63.5     63.9    50.6
# 2005-04-01  2005-04-01 00:00:00  56.7     62.7    61.3     60.3    50.9
# 2005-05-01  2005-05-01 00:00:00  52.9       57    55.6     58.2    47.9
#
#            MPMI_FGI MPMI_PUR MPMI_IMP MPMI_PUI MPMI_PPI MPMI_RMI MPMI_EMP  \
# new_Date
# 2005-01-01     46.6       59     54.3     63.7      NaN     50.1     48.5
# 2005-02-01     47.4       60     55.2     64.8      NaN     47.8     49.7
# 2005-03-01     46.9     62.8     56.9     71.5      NaN     47.7     51.7
# 2005-04-01     46.5       61     54.2     65.2      NaN     48.4     51.8
# 2005-05-01     45.8     54.1     49.4     53.5      NaN     45.2       50
#
#            MPMI_SDT MPMI_BEP  MPMI_50
# new_Date
# 2005-01-01     50.7      NaN     50.0
# 2005-02-01     50.6      NaN     50.0
# 2005-03-01     50.2      NaN     50.0
# 2005-04-01     50.4      NaN     50.0
# 2005-05-01     50.5      NaN     50.0

# %%
df_mpmi_new = df_mpmi.loc["2017-01-01":]
df_mpmi_new.head()
# Out:
#                            DATE  MPMI MPMI_PRO MPMI_NO MPMI_NEO MPMI_BO  \
# new_Date
# 2017-01-01  2017-01-01 00:00:00  51.3     53.1    52.8     50.3    46.3
# 2017-02-01  2017-02-01 00:00:00  51.6     53.7      53     50.8      46
# 2017-03-01  2017-03-01 00:00:00  51.8     54.2    53.3       51    46.1
# 2017-04-01  2017-04-01 00:00:00  51.2     53.8    52.3     50.6      45
# 2017-05-01  2017-05-01 00:00:00  51.2     53.4    52.3     50.7    45.4
#
#            MPMI_FGI MPMI_PUR MPMI_IMP MPMI_PUI MPMI_PPI MPMI_RMI MPMI_EMP  \
# new_Date
# 2017-01-01       45     52.6     50.7     64.5     54.7       48     49.2
# 2017-02-01     47.6     51.4     51.2     64.2     56.3     48.6     49.7
# 2017-03-01     47.3     53.4     50.5     59.3     53.2     48.3       50
# 2017-04-01     48.2     51.9     50.2     51.8     48.7     48.3     49.2
# 2017-05-01     46.6     51.5       50     49.5     47.6     48.5     49.4
#
#            MPMI_SDT MPMI_BEP  MPMI_50
# new_Date
# 2017-01-01     49.8     58.5     50.0
# 2017-02-01     50.5       60     50.0
# 2017-03-01     50.3     58.3     50.0
# 2017-04-01     50.5     56.6     50.0
# 2017-05-01     50.2     56.8     50.0

# %% [markdown]
# #### 업체 규모별 제조업 PMI

# %%
df_mpmi_ent = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = 'MPMI (2)')

# %%
df_mpmi_ent = df_mpmi_ent.iloc[25:]
df_mpmi_ent = df_mpmi_ent.iloc[:, 0:5]

# %%
df_mpmi_ent = df_mpmi_ent.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_mpmi_ent = df_mpmi_ent.rename(columns = {"CN: PMI: Mfg: Large Enterprise": 'MPMI_LAG'})
df_mpmi_ent = df_mpmi_ent.rename(columns = {"CN: PMI: Mfg: Medium Enterprise": 'MPMI_MED'})
df_mpmi_ent = df_mpmi_ent.rename(columns = {"CN: PMI: Mfg: Small Enterprise": 'MPMI_SML'})
df_mpmi_ent = df_mpmi_ent.rename(columns = {"기준": 'MPMI_50'})

# %%
df_mpmi_ent['new_Date'] = pd.to_datetime(df_mpmi_ent['DATE'])
df_mpmi_ent.set_index('new_Date',inplace=True)
# Out:
#                            DATE MPMI_LAG MPMI_MED MPMI_SML  MPMI_50
# new_Date
# 2012-02-01  2012-02-01 00:00:00     50.8     49.5     55.2     50.0
# 2012-03-01  2012-03-01 00:00:00     54.3     50.4     50.9     50.0
# 2012-04-01  2012-04-01 00:00:00     53.8     53.4     49.1     50.0
# 2012-05-01  2012-05-01 00:00:00     51.1     50.8     45.2     50.0
# 2012-06-01  2012-06-01 00:00:00     50.6       50     47.2     50.0

# %%
df_mpmi_ent_new = df_mpmi_ent.loc["2017-01-01":]
df_mpmi_ent_new.head()
# Out:
#                            DATE MPMI_LAG MPMI_MED MPMI_SML  MPMI_50
# new_Date
# 2017-01-01  2017-01-01 00:00:00     52.7     50.8     46.4     50.0
# 2017-02-01  2017-02-01 00:00:00     53.3     50.5     46.4     50.0
# 2017-03-01  2017-03-01 00:00:00     53.3     50.4     48.6     50.0
# 2017-04-01  2017-04-01 00:00:00       52     50.2       50     50.0
# 2017-05-01  2017-05-01 00:00:00     51.2     51.3       51     50.0

# %% [markdown]
# ### (9) 중국 비제조업 PMI

# %%
df_nmpmi = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = 'NMPMI')

# %%
df_nmpmi = df_nmpmi.iloc[25:]
df_nmpmi = df_nmpmi.iloc[:, 0:5]

# %%
df_nmpmi = df_nmpmi.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_nmpmi = df_nmpmi.rename(columns = {"CN: PMI: Service: Business Activity": 'NMPMI_SEV'})
df_nmpmi = df_nmpmi.rename(columns = {"CN: PMI: Construction: Business Activity": 'NMPMI_CON'})
df_nmpmi = df_nmpmi.rename(columns = {"CN: PMI: Non Mfg: Business Activity": 'NMPMI'})
df_nmpmi = df_nmpmi.rename(columns = {"기준": 'MPMI_50'})

# %%
df_nmpmi['new_Date'] = pd.to_datetime(df_nmpmi['DATE'])
df_nmpmi.set_index('new_Date',inplace=True)

# %%
df_nmpmi_new = df_nmpmi.loc["2017-01-01":]
df_nmpmi_new.head()
# Out:
#                            DATE NMPMI_SEV NMPMI_CON NMPMI  MPMI_50
# new_Date
# 2017-01-01  2017-01-01 00:00:00      53.5      61.1  54.6     50.0
# 2017-02-01  2017-02-01 00:00:00      53.2      60.1  54.2     50.0
# 2017-03-01  2017-03-01 00:00:00      54.2      60.5  55.1     50.0
# 2017-04-01  2017-04-01 00:00:00      52.6      61.6    54     50.0
# 2017-05-01  2017-05-01 00:00:00      53.5      60.4  54.5     50.0

# %% [markdown]
# ### 중국 무역수지

# %%
df_tb = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = '무역')

# %%
df_tb = df_tb.iloc[24:]
df_tb = df_tb.iloc[:, 0:5]
df_tb.head()

# %% [markdown]
# ### 중국 가전제품 생산

# %%
# Out:
#            AIR_New WM_New RF_New TV_New data
# 2021-09-01   15081   6995   7638  17482  NaN
# 2021-10-01   14549   7668   7636  17592  NaN
# 2021-11-01   16628   8438   8085  17658  NaN
# 2021-12-01   19635   7856   7578  18884  NaN
# 2022-01-01     NaN    NaN    NaN    NaN  NaN

# %%
# Out:
#          DATE       AIR_New       WM_New       RF_New        TV_New data
# 0  2016-01-01  11056.491525  5882.118644  6224.694915  11822.033898  NaN
# 1  2016-02-01   9986.508475  5312.881356  5622.305085  10677.966102  NaN
# 2  2016-03-01         16391         7270         8671         15790  NaN
# 3  2016-04-01         15829         6071         8733         14234  NaN
# 4  2016-05-01         14323         5854         8552         12723  NaN
# ..        ...           ...          ...          ...           ...  ...
# 67 2021-08-01         14912         6738         7364         15694  NaN
# 68 2021-09-01         15081         6995         7638         17482  NaN
# 69 2021-10-01         14549         7668         7636         17592  NaN
# 70 2021-11-01         16628         8438         8085         17658  NaN
# 71 2021-12-01         19635         7856         7578         18884  NaN
#
# [72 rows x 6 columns]

# %%
# Out:
#          DATE AIR_New WM_New RF_New TV_New  year month
# 67 2021-08-01   14912   6738   7364  15694  2021    08
# 68 2021-09-01   15081   6995   7638  17482  2021    09
# 69 2021-10-01   14549   7668   7636  17592  2021    10
# 70 2021-11-01   16628   8438   8085  17658  2021    11
# 71 2021-12-01   19635   7856   7578  18884  2021    12

# %% [markdown]
# # 4. Plotly를 이용한 시각화

# %% [markdown]
# ### (1) 중국 생산계정 GDP

# %%
fig = make_subplots(rows=3, cols=2, 
    subplot_titles=("GDP", "Primary Industry", "Secondary Industry", "SI: Manufacturing", "SI: Construction", "Tertiary Industry")
)

fig.append_trace(go.Bar(x=df_gdp_pro_new['DATE'], y= df_gdp_pro_new['GDP_YoY_New'], name = 'GDP YoY'), row=1, col=1)
fig.append_trace(go.Bar(x=df_gdp_pro_new['DATE'], y= df_gdp_pro_new['GDP_PI_YoY_New'], name = 'PI GDP YoY'), row=1, col=2)
fig.append_trace(go.Bar(x=df_gdp_pro_new['DATE'], y= df_gdp_pro_new['GDP_SI_YoY_New'], name = 'SI GDP YoY'), row=2, col=1)
fig.append_trace(go.Bar(x=df_gdp_pro_new['DATE'], y= df_gdp_pro_new['GDP_SI_MN_YoY_New'], name = 'SI MN GDP YoY'), row=2, col=2)
fig.append_trace(go.Bar(x=df_gdp_pro_new['DATE'], y= df_gdp_pro_new['GDP_SI_CS_YoY_New'], name = 'SI CS GDP YoY'), row=3, col=1)
fig.append_trace(go.Bar(x=df_gdp_pro_new['DATE'], y= df_gdp_pro_new['GDP_TI_YoY_New'], name = 'TI GDP YoY'), row=3, col=2)

fig.update_layout(height=1500, width=1000, title_text="China GDP Growth Rate")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="365cd284-79cb-4e85-a10a-860d99a23156" class="plotly-graph-div" style="height:1500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("365cd284-79cb-4e85-a10a-860d99a23156")) {                    Plotly.newPlot(                        "365cd284-79cb-4e85-a10a-860d99a23156",                        [{"name":"GDP YoY","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","2016-03-01T00:00:00","2016-06-01T00:00:00","2016-09-01T00:00:00","2016-12-01T00:00:00","2017-03-01T00:00:00","2017-06-01T00:00:00","2017-09-01T00:00:00","2017-12-01T00:00:00","2018-03-01T00:00:00","2018-06-01T00:00:00","2018-09-01T00:00:00","2018-12-01T00:00:00","2019-03-01T00:00:00","2019-06-01T00:00:00","2019-09-01T00:00:00","2019-12-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-09-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-06-01T00:00:00","2021-09-01T00:00:00","2021-12-01T00:00:00"],"y":[7.099999999999994,7.099999999999994,7,6.900000000000006,6.900000000000006,6.799999999999997,6.799999999999997,6.900000000000006,7,7,6.900000000000006,6.799999999999997,6.900000000000006,6.900000000000006,6.700000000000003,6.5,6.299999999999997,6,5.900000000000006,5.799999999999997,-6.900000000000006,3.0999999999999943,4.799999999999997,6.400000000000006,18.299999999999997,7.900000000000006,4.900000000000006,4],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"PI GDP YoY","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","2016-03-01T00:00:00","2016-06-01T00:00:00","2016-09-01T00:00:00","2016-12-01T00:00:00","2017-03-01T00:00:00","2017-06-01T00:00:00","2017-09-01T00:00:00","2017-12-01T00:00:00","2018-03-01T00:00:00","2018-06-01T00:00:00","2018-09-01T00:00:00","2018-12-01T00:00:00","2019-03-01T00:00:00","2019-06-01T00:00:00","2019-09-01T00:00:00","2019-12-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-09-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-06-01T00:00:00","2021-09-01T00:00:00","2021-12-01T00:00:00"],"y":[3.0999999999999943,3.700000000000003,4.099999999999994,4.099999999999994,2.9000000000000057,3.0999999999999943,4,2.9000000000000057,3,3.799999999999997,3.9000000000000057,4.400000000000006,3.200000000000003,3.4000000000000057,3.5999999999999943,3.5,2.700000000000003,3.299999999999997,2.700000000000003,3.4000000000000057,-3.0999999999999943,3.5,4.099999999999994,4.299999999999997,8.099999999999994,7.599999999999994,7.099999999999994,6.400000000000006],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"SI GDP YoY","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","2016-03-01T00:00:00","2016-06-01T00:00:00","2016-09-01T00:00:00","2016-12-01T00:00:00","2017-03-01T00:00:00","2017-06-01T00:00:00","2017-09-01T00:00:00","2017-12-01T00:00:00","2018-03-01T00:00:00","2018-06-01T00:00:00","2018-09-01T00:00:00","2018-12-01T00:00:00","2019-03-01T00:00:00","2019-06-01T00:00:00","2019-09-01T00:00:00","2019-12-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-09-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-06-01T00:00:00","2021-09-01T00:00:00","2021-12-01T00:00:00"],"y":[6.200000000000003,5.900000000000006,5.700000000000003,6,5.799999999999997,6.200000000000003,6.099999999999994,6,6.099999999999994,6.200000000000003,5.799999999999997,5.400000000000006,6.200000000000003,5.900000000000006,5.299999999999997,5.799999999999997,5.299999999999997,4.700000000000003,4.5,5,-9.700000000000003,4.599999999999994,5.900000000000006,6.700000000000003,24.400000000000006,7.5,3.5999999999999943,2.5],"type":"bar","xaxis":"x3","yaxis":"y3"},{"name":"SI MN GDP YoY","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","20 ...

# %% [markdown]
# ### (2) 중국 지출계정 GDP

# %%
fig = make_subplots(rows=2, cols=1, shared_yaxes=True)

#fig = go.Figure()
fig.add_trace(go.Bar(x=df_gdp_exp_new['DATE'], y=df_gdp_exp_new['GDP_SH_FCE'], name = 'Share to GDP Growth: FCE'), 1, 1)
fig.add_trace(go.Bar(x=df_gdp_exp_new['DATE'], y=df_gdp_exp_new['GDP_SH_GCF'], name = 'Share to GDP Growth: GCF'), 1, 1)
fig.add_trace(go.Bar(x=df_gdp_exp_new['DATE'], y=df_gdp_exp_new['GDP_SH_NEX'], name = 'Share to GDP Growth: NEX'), 1, 1)


fig.add_trace(go.Bar(x=df_gdp_exp_new['DATE'], y=df_gdp_exp_new['GDP_CO_FCE'], name = 'Contribution to GDP Growth: FCE'), 2, 1)
fig.add_trace(go.Bar(x=df_gdp_exp_new['DATE'], y=df_gdp_exp_new['GDP_CO_GCF'], name = 'Contribution to GDP Growth: GCF'), 2, 1)
fig.add_trace(go.Bar(x=df_gdp_exp_new['DATE'], y=df_gdp_exp_new['GDP_CO_NEX'], name = 'Contribution to GDP Growth: NEX'), 2, 1)

fig.update_layout(height = 1000, width = 1000, barmode='relative', title_text='Share and Contribution to GDP Growth')
fig.show()
# Out:
# <div>                            <div id="8986dcfc-bcaf-47db-b08f-f75cac417e92" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8986dcfc-bcaf-47db-b08f-f75cac417e92")) {                    Plotly.newPlot(                        "8986dcfc-bcaf-47db-b08f-f75cac417e92",                        [{"name":"Share to GDP Growth: FCE","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","2016-03-01T00:00:00","2016-06-01T00:00:00","2016-09-01T00:00:00","2016-12-01T00:00:00","2017-03-01T00:00:00","2017-06-01T00:00:00","2017-09-01T00:00:00","2017-12-01T00:00:00","2018-03-01T00:00:00","2018-06-01T00:00:00","2018-09-01T00:00:00","2018-12-01T00:00:00","2019-03-01T00:00:00","2019-06-01T00:00:00","2019-09-01T00:00:00","2019-12-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-09-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-06-01T00:00:00","2021-09-01T00:00:00","2021-12-01T00:00:00"],"y":[64.1,60.6,51.3,63.5,78.1,55.9,58.4,72,76.2,49.7,60.1,42.4,68.5,68.3,62.9,57.5,66.1,52.3,59.2,57.2,58.4,-68.4,35.5,44.8,50.7,74.1,77.5,85.3],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Share to GDP Growth: GCF","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","2016-03-01T00:00:00","2016-06-01T00:00:00","2016-09-01T00:00:00","2016-12-01T00:00:00","2017-03-01T00:00:00","2017-06-01T00:00:00","2017-09-01T00:00:00","2017-12-01T00:00:00","2018-03-01T00:00:00","2018-06-01T00:00:00","2018-09-01T00:00:00","2018-12-01T00:00:00","2019-03-01T00:00:00","2019-06-01T00:00:00","2019-09-01T00:00:00","2019-12-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-09-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-06-01T00:00:00","2021-09-01T00:00:00","2021-12-01T00:00:00"],"y":[16.7,47,59.1,39,38.3,49.1,52.4,42.5,28.4,49.8,38.4,40.1,47.8,40.3,44.7,40.7,13.4,33.7,23.3,43,24,154.4,40.5,31.5,24,12.8,7.8,-11.6],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Share to GDP Growth: NEX","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","2016-03-01T00:00:00","2016-06-01T00:00:00","2016-09-01T00:00:00","2016-12-01T00:00:00","2017-03-01T00:00:00","2017-06-01T00:00:00","2017-09-01T00:00:00","2017-12-01T00:00:00","2018-03-01T00:00:00","2018-06-01T00:00:00","2018-09-01T00:00:00","2018-12-01T00:00:00","2019-03-01T00:00:00","2019-06-01T00:00:00","2019-09-01T00:00:00","2019-12-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-09-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-06-01T00:00:00","2021-09-01T00:00:00","2021-12-01T00:00:00"],"y":[19.2,-7.6,-10.4,-2.5,-16.4,-5,-10.7,-14.5,-4.5,0.5,1.5,17.4,-16.3,-8.5,-7.7,1.9,20.5,14,17.5,-0.2,17.5,14,24,23.7,25.3,13.1,14.7,26.4],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Contribution to GDP Growth: FCE","x":["2015-03-01T00:00:00","2015-06-01T00:00:00","2015-09-01T00:00:00","2015-12-01T00:00:00","2016-03-01T00:00:00","2016-06-01T00:00:00","2016-09-01T00:00:00","2016-12-01T00:00:00","2017-03-01T00:00:00","2017-06-01T00:00:00","2017-09-01T00:00:00","2017-12-01T00:00:00","2018-03-01T00:00:00","2018-06-01T00:00:00","2018-09-01T00:00:00","2018-12-01T00:00:00","2019-03-01T00:00:00","2019-06-01T00:00:00","2019-09-01T00:00:00","2019-12-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-09-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-06-01T00:00:00","2021-09-01T00:00:00","2021-12-01T00:00:00"],"y":[4.487,4.242,3.5397,4.318,5.3889,3.8012,3.9712,4.968,5.334,3.479,4.1469,2.8832,4.7265,4.7127,4.2143,3.7375,4.1643,3.138,3.4928,3.3176,-4.0296,-2.1204,1.704,2.8672,9.2781,5.8539,3.7975,3.412],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Contribution to GDP Growth: GCF","x":["2015-03-01T0 ...

# %% [markdown]
# ### (3) 중국 물가지수

# %%
fig = make_subplots(rows=5, cols=1, 
    subplot_titles=("CPI", "Core CPI", "PPI", "PPI: Production Goods", "PPI: Consumer Goods")
)

fig.append_trace(go.Scatter(x=df_pi_new['DATE'], y= df_pi_new['CPI_New'], name = 'CPI YoY', mode='lines+markers'), row=1, col=1)
fig.append_trace(go.Scatter(x=df_pi_new['DATE'], y= df_pi_new['CCPI_New'], name = 'Core CPI YoY', mode='lines+markers'), row=2, col=1)
fig.append_trace(go.Scatter(x=df_pi_new['DATE'], y= df_pi_new['PPI_New'], name = 'PPI YoY', mode='lines+markers'), row=3, col=1)
fig.append_trace(go.Scatter(x=df_pi_new['DATE'], y= df_pi_new['PPPI_New'], name = 'PPI PG YoY', mode='lines+markers'), row=4, col=1)
fig.append_trace(go.Scatter(x=df_pi_new['DATE'], y= df_pi_new['CPPI_New'], name = 'PPI CG YoY', mode='lines+markers'), row=5, col=1)


fig.update_layout(height=1500, width=1000, title_text="China Price Indice")
fig.show()
# Out:
# <div>                            <div id="b2334835-305f-457a-9436-f87879b1b029" class="plotly-graph-div" style="height:1500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2334835-305f-457a-9436-f87879b1b029")) {                    Plotly.newPlot(                        "b2334835-305f-457a-9436-f87879b1b029",                        [{"mode":"lines+markers","name":"CPI YoY","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[2.5,0.7999999999999972,0.9000000000000057,1.2000000000000028,1.5,1.5,1.4000000000000057,1.7999999999999972,1.5999999999999943,1.9000000000000057,1.7000000000000028,1.7999999999999972,1.5,2.9000000000000057,2.0999999999999943,1.7999999999999972,1.7999999999999972,1.9000000000000057,2.0999999999999943,2.299999999999997,2.5,2.5,2.200000000000003,1.9000000000000057,1.7000000000000028,1.5,2.299999999999997,2.5,2.700000000000003,2.700000000000003,2.799999999999997,2.799999999999997,3,3.799999999999997,4.5,4.5,5.400000000000006,5.200000000000003,4.299999999999997,3.299999999999997,2.4000000000000057,2.5,2.700000000000003,2.4000000000000057,1.7000000000000028,0.5,-0.5,0.20000000000000284,-0.29999999999999716,-0.20000000000000284,0.4000000000000057,0.9000000000000057,1.2999999999999972,1.0999999999999943,1,0.7999999999999972,0.7000000000000028,1.5,2.299999999999997,1.5,0.9000000000000057,0.9000000000000057],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"Core CPI YoY","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01 ...

# %% [markdown]
# ### (4) 중국 통화량

# %%
fig = px.line(df_ac, x='DATE', y='M0', title='Money Supply M0 YoY in China')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=6, label="5y", step="year", stepmode="backward"),
            dict(count=11, label="10y", step="year", stepmode="backward"),
            #dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <div>                            <div id="067f68d1-7c47-411d-9b9b-047f4c7873ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("067f68d1-7c47-411d-9b9b-047f4c7873ec")) {                    Plotly.newPlot(                        "067f68d1-7c47-411d-9b9b-047f4c7873ec",                        [{"hovertemplate":"DATE=%{x}<br>M0=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00","1998-05-01T00:00:00","1998-06-01T00:00:00","1998-07-01T00:00:00","1998-08-01T00:00:00","1998-09-01T00:00:00","1998-10-01T00:00:00","1998-11-01T00:00:00","1998-12-01T00:00:00","1999-01-01T00:00:00","1999-02-01T00:00:00","1999-03-01T00:00:00","1999-04-01T00:00:00","1999-05-01T00:00:00","1999-06-01T00:00:00","1999-07-01T00:00:00","1999-08-01T00:00:00","1999-09-01T00:00:00","1999-10-01T00:00:00","1999-11-01T00:00:00","1999-12-01T00:00:00","2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00:00:00","2001-02-01T00:00:00","2001-03-01T00:00:00","2001-04-01T00:00:00","2001-05-01T00:00:00","2001-06-01T00:00:00","2001-07-01T00:00:00","2001-08-01T00:00:00","2001-09-01T00:00:00","2001-10-01T00:00:00","2001-11-01T00:00:00","2001-12-01T00:00:00","2002-01-01T00:00:00","2002-02-01T00:00:00","2002-03-01T00:00:00","2002-04-01T00:00:00","2002-05-01T00:00:00","2002-06-01T00:00:00","2002-07-01T00:00:00","2002-08-01T00:00:00","2002-09-01T00:00:00","2002-10-01T00:00:00","2002-11-01T00:00:00","2002-12-01T00:00:00","2003-01-01T00:00:00","2003-02-01T00:00:00","2003-03-01T00:00:00","2003-04-01T00:00:00","2003-05-01T00:00:00","2003-06-01T00:00:00","2003-07-01T00:00:00","2003-08-01T00:00:00","2003-09-01T00:00:00","2003-10-01T00:00:00","2003-11-01T00:00:00","2003-12-01T00:00:00","2004-01-01T00:00:00","2004-02-01T00:00:00","2004-03-01T00:00:00","2004-04-01T00:00:00","2004-05-01T00:00:00","2004-06-01T00:00:00","2004-07-01T00:00:00","2004-08-01T00:00:00","2004-09-01T00:00:00","2004-10-01T00:00:00","2004-11-01T00:00:00","2004-12-01T00:00:00","2005-01-01T00:00:00","2005-02-01T00:00:00","2005-03-01T00:00:00","2005-04-01T00:00:00","2005-05-01T00:00:00","2005-06-01T00:00:00","2005-07-01T00:00:00","2005-08-01T00:00:00","2005-09-01T00:00:00","2005-10-01T00:00:00","2005-11-01T00:00:00","2005-12-01T00:00:00","2006-01-01T00:00:00","2006-02-01T00:00:00","2006-03-01T00:00:00","2006-04-01T00:00:00","2006-05-01T00:00:00","2006-06-01T00:00:00","2006-07-01T00:00:00","2006-08-01T00:00:00","2006-09-01T00:00:00","2006-10-01T00:00:00","2006-11-01T00:00:00","2006-12-01T00:00:00","2007-01-01T00:00:00","2007-02-01T00:00:00","2007-03-01T00:00:00","2007-04-01T00:00:00","2007-05-01T00:00:00","2007-06-01T00:00:00","2007-07-01T00:00:00","2007-08-01T00:00:00","2007-09-01T00:00:00","2007-10-01T00:00:00","2007-11-01T00:00:00","2007-12-01T00:00:00","2008-01-01T00:00:00","2008-02-01T00:00:00","2008-03-01T00:00:00","2008-04-01T00:00:00","2008-05-01T00:00:00","2008-06-01T00:00:00","2008-07-01T00:00:00","2008-08-01T00:00:00","2008-09-01T00:00:00","2008-10-01T00:00:00","2008-11-01T00:00:00","2008-12-01T00:00:00","2009-01-01T00:00:00","2009-02-01T00:00:00","2009-03-01T00:00:00","2009-04-01T00:00:00","2009-05-01T00:00:00","2009-06-01T00:00:00","20 ...

# %%
fig = px.line(df_ac, x='DATE', y='M1', title='Money Supply M1 YoY in China')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=6, label="5y", step="year", stepmode="backward"),
            dict(count=11, label="10y", step="year", stepmode="backward"),
            #dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <div>                            <div id="9677429a-44fa-444d-8e8d-4b60de1ee82b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9677429a-44fa-444d-8e8d-4b60de1ee82b")) {                    Plotly.newPlot(                        "9677429a-44fa-444d-8e8d-4b60de1ee82b",                        [{"hovertemplate":"DATE=%{x}<br>M1=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00","1998-05-01T00:00:00","1998-06-01T00:00:00","1998-07-01T00:00:00","1998-08-01T00:00:00","1998-09-01T00:00:00","1998-10-01T00:00:00","1998-11-01T00:00:00","1998-12-01T00:00:00","1999-01-01T00:00:00","1999-02-01T00:00:00","1999-03-01T00:00:00","1999-04-01T00:00:00","1999-05-01T00:00:00","1999-06-01T00:00:00","1999-07-01T00:00:00","1999-08-01T00:00:00","1999-09-01T00:00:00","1999-10-01T00:00:00","1999-11-01T00:00:00","1999-12-01T00:00:00","2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00:00:00","2001-02-01T00:00:00","2001-03-01T00:00:00","2001-04-01T00:00:00","2001-05-01T00:00:00","2001-06-01T00:00:00","2001-07-01T00:00:00","2001-08-01T00:00:00","2001-09-01T00:00:00","2001-10-01T00:00:00","2001-11-01T00:00:00","2001-12-01T00:00:00","2002-01-01T00:00:00","2002-02-01T00:00:00","2002-03-01T00:00:00","2002-04-01T00:00:00","2002-05-01T00:00:00","2002-06-01T00:00:00","2002-07-01T00:00:00","2002-08-01T00:00:00","2002-09-01T00:00:00","2002-10-01T00:00:00","2002-11-01T00:00:00","2002-12-01T00:00:00","2003-01-01T00:00:00","2003-02-01T00:00:00","2003-03-01T00:00:00","2003-04-01T00:00:00","2003-05-01T00:00:00","2003-06-01T00:00:00","2003-07-01T00:00:00","2003-08-01T00:00:00","2003-09-01T00:00:00","2003-10-01T00:00:00","2003-11-01T00:00:00","2003-12-01T00:00:00","2004-01-01T00:00:00","2004-02-01T00:00:00","2004-03-01T00:00:00","2004-04-01T00:00:00","2004-05-01T00:00:00","2004-06-01T00:00:00","2004-07-01T00:00:00","2004-08-01T00:00:00","2004-09-01T00:00:00","2004-10-01T00:00:00","2004-11-01T00:00:00","2004-12-01T00:00:00","2005-01-01T00:00:00","2005-02-01T00:00:00","2005-03-01T00:00:00","2005-04-01T00:00:00","2005-05-01T00:00:00","2005-06-01T00:00:00","2005-07-01T00:00:00","2005-08-01T00:00:00","2005-09-01T00:00:00","2005-10-01T00:00:00","2005-11-01T00:00:00","2005-12-01T00:00:00","2006-01-01T00:00:00","2006-02-01T00:00:00","2006-03-01T00:00:00","2006-04-01T00:00:00","2006-05-01T00:00:00","2006-06-01T00:00:00","2006-07-01T00:00:00","2006-08-01T00:00:00","2006-09-01T00:00:00","2006-10-01T00:00:00","2006-11-01T00:00:00","2006-12-01T00:00:00","2007-01-01T00:00:00","2007-02-01T00:00:00","2007-03-01T00:00:00","2007-04-01T00:00:00","2007-05-01T00:00:00","2007-06-01T00:00:00","2007-07-01T00:00:00","2007-08-01T00:00:00","2007-09-01T00:00:00","2007-10-01T00:00:00","2007-11-01T00:00:00","2007-12-01T00:00:00","2008-01-01T00:00:00","2008-02-01T00:00:00","2008-03-01T00:00:00","2008-04-01T00:00:00","2008-05-01T00:00:00","2008-06-01T00:00:00","2008-07-01T00:00:00","2008-08-01T00:00:00","2008-09-01T00:00:00","2008-10-01T00:00:00","2008-11-01T00:00:00","2008-12-01T00:00:00","2009-01-01T00:00:00","2009-02-01T00:00:00","2009-03-01T00:00:00","2009-04-01T00:00:00","2009-05-01T00:00:00","2009-06-01T00:00:00","20 ...

# %%
fig = px.line(df_ac, x='DATE', y='M2', title='Money Supply M2 YoY in China')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=6, label="5y", step="year", stepmode="backward"),
            dict(count=11, label="10y", step="year", stepmode="backward"),
            #dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <div>                            <div id="d8f1105f-405a-42fc-b7af-17f4c128bc51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8f1105f-405a-42fc-b7af-17f4c128bc51")) {                    Plotly.newPlot(                        "d8f1105f-405a-42fc-b7af-17f4c128bc51",                        [{"hovertemplate":"DATE=%{x}<br>M2=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00","1998-05-01T00:00:00","1998-06-01T00:00:00","1998-07-01T00:00:00","1998-08-01T00:00:00","1998-09-01T00:00:00","1998-10-01T00:00:00","1998-11-01T00:00:00","1998-12-01T00:00:00","1999-01-01T00:00:00","1999-02-01T00:00:00","1999-03-01T00:00:00","1999-04-01T00:00:00","1999-05-01T00:00:00","1999-06-01T00:00:00","1999-07-01T00:00:00","1999-08-01T00:00:00","1999-09-01T00:00:00","1999-10-01T00:00:00","1999-11-01T00:00:00","1999-12-01T00:00:00","2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00:00:00","2001-02-01T00:00:00","2001-03-01T00:00:00","2001-04-01T00:00:00","2001-05-01T00:00:00","2001-06-01T00:00:00","2001-07-01T00:00:00","2001-08-01T00:00:00","2001-09-01T00:00:00","2001-10-01T00:00:00","2001-11-01T00:00:00","2001-12-01T00:00:00","2002-01-01T00:00:00","2002-02-01T00:00:00","2002-03-01T00:00:00","2002-04-01T00:00:00","2002-05-01T00:00:00","2002-06-01T00:00:00","2002-07-01T00:00:00","2002-08-01T00:00:00","2002-09-01T00:00:00","2002-10-01T00:00:00","2002-11-01T00:00:00","2002-12-01T00:00:00","2003-01-01T00:00:00","2003-02-01T00:00:00","2003-03-01T00:00:00","2003-04-01T00:00:00","2003-05-01T00:00:00","2003-06-01T00:00:00","2003-07-01T00:00:00","2003-08-01T00:00:00","2003-09-01T00:00:00","2003-10-01T00:00:00","2003-11-01T00:00:00","2003-12-01T00:00:00","2004-01-01T00:00:00","2004-02-01T00:00:00","2004-03-01T00:00:00","2004-04-01T00:00:00","2004-05-01T00:00:00","2004-06-01T00:00:00","2004-07-01T00:00:00","2004-08-01T00:00:00","2004-09-01T00:00:00","2004-10-01T00:00:00","2004-11-01T00:00:00","2004-12-01T00:00:00","2005-01-01T00:00:00","2005-02-01T00:00:00","2005-03-01T00:00:00","2005-04-01T00:00:00","2005-05-01T00:00:00","2005-06-01T00:00:00","2005-07-01T00:00:00","2005-08-01T00:00:00","2005-09-01T00:00:00","2005-10-01T00:00:00","2005-11-01T00:00:00","2005-12-01T00:00:00","2006-01-01T00:00:00","2006-02-01T00:00:00","2006-03-01T00:00:00","2006-04-01T00:00:00","2006-05-01T00:00:00","2006-06-01T00:00:00","2006-07-01T00:00:00","2006-08-01T00:00:00","2006-09-01T00:00:00","2006-10-01T00:00:00","2006-11-01T00:00:00","2006-12-01T00:00:00","2007-01-01T00:00:00","2007-02-01T00:00:00","2007-03-01T00:00:00","2007-04-01T00:00:00","2007-05-01T00:00:00","2007-06-01T00:00:00","2007-07-01T00:00:00","2007-08-01T00:00:00","2007-09-01T00:00:00","2007-10-01T00:00:00","2007-11-01T00:00:00","2007-12-01T00:00:00","2008-01-01T00:00:00","2008-02-01T00:00:00","2008-03-01T00:00:00","2008-04-01T00:00:00","2008-05-01T00:00:00","2008-06-01T00:00:00","2008-07-01T00:00:00","2008-08-01T00:00:00","2008-09-01T00:00:00","2008-10-01T00:00:00","2008-11-01T00:00:00","2008-12-01T00:00:00","2009-01-01T00:00:00","2009-02-01T00:00:00","2009-03-01T00:00:00","2009-04-01T00:00:00","2009-05-01T00:00:00","2009-06-01T00:00:00","20 ...

# %% [markdown]
# ### (5) 중국 사회융자총액

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(
    go.Scatter(
        y=df_af_new['LC_AF_YoY'],
        x=df_af_new['DATE'],
        name = 'Local Currency'
    ),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(
        y=df_af_new['SBS_AF_YoY'],
        x=df_af_new['DATE'],
        name = 'Shadow Banking System'
    ),
    secondary_y=True,
)

fig.show()
# Out:
# <div>                            <div id="270eb92e-f139-4be1-b291-9f4e65aaf6a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("270eb92e-f139-4be1-b291-9f4e65aaf6a2")) {                    Plotly.newPlot(                        "270eb92e-f139-4be1-b291-9f4e65aaf6a2",                        [{"name":"Local Currency","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[12.81396602549445,12.936052646661489,12.597929068622893,13.052388386236391,13.171933486433062,13.132256795703846,13.530005032068914,13.768234708955674,13.526683575361753,13.508484980748525,13.683343759368993,13.1607322370354,13.21093700043441,13.07449249994077,12.921669920103952,12.81201837810826,12.642879820402953,12.685475109240429,12.908434924024004,12.925215545843471,13.00408786356735,12.973670849964481,12.922272684138946,13.154688111237434,13.556691123956611,13.23673460052348,13.772739067212768,13.526857252028556,13.387169918893814,13.209908629216605,12.779320876214605,12.603980145075777,12.764018129493483,12.49694676774511,12.471843973012442,12.549725393162081,12.223761418959622,12.06810915426808,12.72725398486716,13.07676419166015,13.28134979423725,13.299999999997869,13.299999999997825,13.29999999999718,13.2000000000011,13.299999999999311,13.299999999999223,13.19999999999788,13.099999999997447,13.500000000002377,12.999999999997168,12.699999999999513,12.50000000000231,12.59304453935326,12.406015037593976,12.209931465672707,11.981457268513008,12.005683163627756,11.762980346142559,11.620046620046608,11.572886380480018,11.235573659198916],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Shadow Banking System","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:0 ...

# %% [markdown]
# ### (6) 중국 산업생산

# %%
fig = px.bar(new_data_ip, y='IP_New', title='Industrial Prodution YoY in China')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=6, label="5y", step="year", stepmode="backward"),
            dict(count=11, label="10y", step="year", stepmode="backward"),
            #dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <div>                            <div id="50e24861-88b2-420a-9e48-ace10c4b566f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50e24861-88b2-420a-9e48-ace10c4b566f")) {                    Plotly.newPlot(                        "50e24861-88b2-420a-9e48-ace10c4b566f",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>IP_New=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"xaxis":"x","y":[6.3,6.3,7.6,6.5,6.5,7.6,6.4,6.0,6.6,6.2,6.1,6.2,7.2,7.2,6.0,7.0,6.8,6.0,6.0,6.1,5.8,5.9,5.4,5.7,5.3,5.3,8.5,5.4,5.0,6.3,4.8,4.4,5.8,4.7,6.2,6.9,-13.5,-13.5,-1.1,3.9,4.4,4.8,4.8,5.6,6.9,6.9,7.0,7.3,35.1,35.1,14.1,9.8,8.8,8.3,6.4,5.3,3.1,3.5,3.8,4.3,7.5,7.5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"he ...

# %% [markdown]
# ### (7) 중국 고정자산투자

# %%
fig = make_subplots(
    rows=5, cols=2,
    specs=[[{"colspan": 2}, None],
            [{}, {}],
            [{}, {}],
            [{}, {}],
            [{}, {}]],

    subplot_titles=("Total", "SOE", "Private", "Construction & Installation", "Equipment Purchase", 
                    "Primary Industry", "Secondary Industry", "SI: Construction", "Tertiary Industry")
)

fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_YoY'], name = 'Total'), row=1, col=1)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_SOE_YoY'], name = 'SOE'), row=2, col=1)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_PRV_YoY'], name = 'Private'), row=2, col=2)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_CON_YoY'], name = 'C&I'), row=3, col=1)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_EQU_YoY'], name = 'EP'), row=3, col=2)
#fig.append_trace(go.Bar(x=df_fa['DATE'], y= df_fa['FA_OTH_YoY'], name = 'Others'), row=4, col=1)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_PI_YoY'], name = 'Primary Industry'), row=4, col=1)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_SI_YoY'], name = 'Secondary Industry'), row=4, col=2)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_SI_CON_YoY'], name = 'Construction'), row=5, col=1)
fig.append_trace(go.Bar(x=df_fa_new['DATE'], y= df_fa_new['FA_TI_YoY'], name = 'Tertiary Industry'), row=5, col=2)

fig.update_layout(height=2500, width=1000, title_text="China Fixed Asset Investment")
fig.show()
# Out:
# <div>                            <div id="84f6a6a8-cb21-47ca-a426-4164de1afea9" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84f6a6a8-cb21-47ca-a426-4164de1afea9")) {                    Plotly.newPlot(                        "84f6a6a8-cb21-47ca-a426-4164de1afea9",                        [{"name":"Total","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[8.9,8.9,9.2,8.9,8.6,8.6,8.3,7.8,7.5,7.3,7.2,7.2,7.9,7.9,7.5,7,6.1,6,5.5,5.3,5.4,5.7,5.9,5.9,6.1,6.1,6.3,6.1,5.6,5.8,5.7,5.5,5.4,5.2,5.2,5.4,-24.5,-24.5,-16.1,-10.3,-6.3,-3.1,-1.6,-0.3,0.8,1.8,2.6,2.9,35,35,25.6,19.9,15.4,12.6,10.3,8.9,7.3,6.1,5.2,4.9,12.2,12.2],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"SOE","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[14.4,14.4,13.6,13.8,12.6,12,11.7,11.2,11,10.9,11,10.1,9.2,9.2,7.1,6.5,4.1,3,1.5,1.1,1.2,1.8,2.3,1.9,5.5,5.5,6.7,7.8,7.2,6.9,7.1,7.1,7.3,7.4,6.9,6.8,-23.1,-23.1,-12.8,-6.9,-1.9,2.1,3.8,3.2,4,4.9,5.6,5.3,32.9,32.9,25.3,18.6,11.8,9.6,7.1,6.2,5,4.1,3,2.9,14.1,14.1],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Private","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00 ...

# %% [markdown]
# ### (8) 중국 제조업 PMI

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_mpmi_new['DATE'], y=df_mpmi_new['MPMI'],
                    mode='lines+markers',
                    name='Manufacturing PMI'))
fig.add_trace(go.Scatter(x=df_mpmi_new['DATE'], y=df_mpmi_new['MPMI_PRO'],
                    mode='lines+markers',
                    name='Production'))
fig.add_trace(go.Scatter(x=df_mpmi_new['DATE'], y=df_mpmi_new['MPMI_NO'],
                    mode='lines+markers', 
                    name='New Order'))
fig.add_trace(go.Scatter(x=df_mpmi_new['DATE'], y=df_mpmi_new['MPMI_50'],
                    mode='lines', 
                    name='Base Line'))
fig.show()
# Out:
# <div>                            <div id="b5097a96-1f3c-4501-85d6-3521f4d0ef86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5097a96-1f3c-4501-85d6-3521f4d0ef86")) {                    Plotly.newPlot(                        "b5097a96-1f3c-4501-85d6-3521f4d0ef86",                        [{"mode":"lines+markers","name":"Manufacturing PMI","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[51.3,51.6,51.8,51.2,51.2,51.7,51.4,51.7,52.4,51.6,51.8,51.6,51.3,50.3,51.5,51.4,51.9,51.5,51.2,51.3,50.8,50.2,50,49.4,49.5,49.2,50.5,50.1,49.4,49.4,49.7,49.5,49.8,49.3,50.2,50.2,50,35.7,52,50.8,50.6,50.9,51.1,51,51.5,51.4,52.1,51.9,51.3,50.6,51.9,51.1,51,50.9,50.4,50.1,49.6,49.2,50.1,50.3,50.1,50.2],"type":"scatter"},{"mode":"lines+markers","name":"Production","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[53.1,53.7,54.2,53.8,53.4,54.4,53.5,54.1,54.7,53.4,54.3,54,53.5,50.7,53.1,53.1,54.1,53.6,53,53.3,53,52,51.9,50.8,50.9,49.5,52.7,52.1,51.7,51.3,52.1,51.9,52.3,50.8,52.6,53.2,51.3,27.8,54.1,53.7,53.2,53.9,54,53.5,54,53.9,54.7,54.2,53.5,51.9,53.9,52.2,52.7,51.9,51,50.9,49.5,48.4,52,51.4,50.9,50.4],"type":"sc ...

# %% [markdown]
# #### 기업 규모별 제조업 PMI

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_mpmi_ent_new['DATE'], y=df_mpmi_ent_new['MPMI_LAG'],
                    mode='lines+markers',
                    name='Large MPMI'))
fig.add_trace(go.Scatter(x=df_mpmi_ent_new['DATE'], y=df_mpmi_ent_new['MPMI_MED'],
                    mode='lines+markers',
                    name='Medium MPMI'))
fig.add_trace(go.Scatter(x=df_mpmi_ent_new['DATE'], y=df_mpmi_ent_new['MPMI_SML'],
                    mode='lines+markers', 
                    name='Small MPMI'))
fig.add_trace(go.Scatter(x=df_mpmi_ent_new['DATE'], y=df_mpmi_ent_new['MPMI_50'],
                    mode='lines', 
                    name='Base Line'))
fig.show()
# Out:
# <div>                            <div id="04a1988d-e876-4b11-b45e-6df6fc51b7f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04a1988d-e876-4b11-b45e-6df6fc51b7f9")) {                    Plotly.newPlot(                        "04a1988d-e876-4b11-b45e-6df6fc51b7f9",                        [{"mode":"lines+markers","name":"Large MPMI","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[52.7,53.3,53.3,52,51.2,52.7,52.9,52.8,53.8,53.1,52.9,53,52.6,52.2,52.4,52,53.1,52.9,52.4,52.1,52.1,51.6,50.6,50.1,51.3,51.5,51.1,50.8,50.3,49.9,50.7,50.4,50.8,49.9,50.9,50.6,50.4,36.3,52.6,51.1,51.6,52.1,52,52,52.5,52.6,53,52.7,52.1,52.2,52.7,51.7,51.8,51.7,51.7,50.3,50.4,50.3,50.2,51.3,51.6,51.8],"type":"scatter"},{"mode":"lines+markers","name":"Medium MPMI","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[50.8,50.5,50.4,50.2,51.3,50.5,49.6,51,51.1,49.8,50.5,50.4,50.1,49,50.4,50.7,51,49.9,49.9,50.4,48.7,47.7,49.1,48.4,47.2,46.9,49.9,49.1,48.8,49.1,48.7,48.2,48.6,49,49.5,51.4,50.1,35.5,51.5,50.2,48.8,50.2,51.2,51.6,50.7,50.6,52,52.7,51.4,49.6,51.6,50.3,51.1,50.8,50,51.2,49.7,48.6,51.2,51.3,50.5,51.4],"type":"scatte ...

# %% [markdown]
# ### (9) 중국 비제조업 PMI

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_nmpmi_new['DATE'], y=df_nmpmi_new['NMPMI'],
                    mode='lines+markers',
                    name='NMPMI'))
fig.add_trace(go.Scatter(x=df_nmpmi_new['DATE'], y=df_nmpmi_new['NMPMI_SEV'],
                    mode='lines+markers',
                    name='Service NMPM'))
fig.add_trace(go.Scatter(x=df_nmpmi_new['DATE'], y=df_nmpmi_new['NMPMI_CON'],
                    mode='lines+markers', 
                    name='Construction NMPMI'))
fig.add_trace(go.Scatter(x=df_nmpmi_new['DATE'], y=df_nmpmi_new['MPMI_50'],
                    mode='lines', 
                    name='Base Line'))
fig.show()
# Out:
# <div>                            <div id="ba4c2173-3ed0-44e7-a235-18626a6941af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba4c2173-3ed0-44e7-a235-18626a6941af")) {                    Plotly.newPlot(                        "ba4c2173-3ed0-44e7-a235-18626a6941af",                        [{"mode":"lines+markers","name":"NMPMI","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[54.6,54.2,55.1,54,54.5,54.9,54.5,53.4,55.4,54.3,54.8,55,55.3,54.4,54.6,54.8,54.9,55,54,54.2,54.9,53.9,53.4,53.8,54.7,54.3,54.8,54.3,54.3,54.2,53.7,53.8,53.7,52.8,54.4,53.5,54.1,29.6,52.3,53.2,53.6,54.4,54.2,55.2,55.9,56.2,56.4,55.7,52.4,51.4,56.3,54.9,55.2,53.5,53.3,47.5,53.2,52.4,52.3,52.7,51.1,51.6],"type":"scatter"},{"mode":"lines+markers","name":"Service NMPM","x":["2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"y":[53.5,53.2,54.2,52.6,53.5,53.8,53.1,52.6,54.4,53.5,53.6,53.4,54.4,53.8,53.6,53.8,54,54,53,53.4,53.4,52.1,52.4,52.3,53.6,53.5,53.6,53.3,53.5,53.4,52.9,52.5,53,51.4,53.5,53,53.1,30.1,51.8,52.1,52.3,53.4,53.1,54.3,55.2,55.5,55.7,54.8,51.1,50.8,55.2,54.4,54.3,52.3,52.5,45.2,52.4,51.6,51.1,52,50.3,50.5],"type":"scatte ...

# %% [markdown]
# ### 중국 가전제품 생산

# %%
# Out:
# <div>                            <div id="6aac0595-9aa7-4615-b4e7-4f8f21acf70c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6aac0595-9aa7-4615-b4e7-4f8f21acf70c")) {                    Plotly.newPlot(                        "6aac0595-9aa7-4615-b4e7-4f8f21acf70c",                        [{"hovertemplate":"DATE=%{x}<br>AIR_New=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1986-01-01T00:00:00","1986-02-01T00:00:00","1986-03-01T00:00:00","1986-04-01T00:00:00","1986-05-01T00:00:00","1986-06-01T00:00:00","1986-07-01T00:00:00","1986-08-01T00:00:00","1986-09-01T00:00:00","1986-10-01T00:00:00","1986-11-01T00:00:00","1986-12-01T00:00:00","1987-01-01T00:00:00","1987-02-01T00:00:00","1987-03-01T00:00:00","1987-04-01T00:00:00","1987-05-01T00:00:00","1987-06-01T00:00:00","1987-07-01T00:00:00","1987-08-01T00:00:00","1987-09-01T00:00:00","1987-10-01T00:00:00","1987-11-01T00:00:00","1987-12-01T00:00:00","1988-01-01T00:00:00","1988-02-01T00:00:00","1988-03-01T00:00:00","1988-04-01T00:00:00","1988-05-01T00:00:00","1988-06-01T00:00:00","1988-07-01T00:00:00","1988-08-01T00:00:00","1988-09-01T00:00:00","1988-10-01T00:00:00","1988-11-01T00:00:00","1988-12-01T00:00:00","1989-01-01T00:00:00","1989-02-01T00:00:00","1989-03-01T00:00:00","1989-04-01T00:00:00","1989-05-01T00:00:00","1989-06-01T00:00:00","1989-07-01T00:00:00","1989-08-01T00:00:00","1989-09-01T00:00:00","1989-10-01T00:00:00","1989-11-01T00:00:00","1989-12-01T00:00:00","1990-01-01T00:00:00","1990-02-01T00:00:00","1990-03-01T00:00:00","1990-04-01T00:00:00","1990-05-01T00:00:00","1990-06-01T00:00:00","1990-07-01T00:00:00","1990-08-01T00:00:00","1990-09-01T00:00:00","1990-10-01T00:00:00","1990-11-01T00:00:00","1990-12-01T00:00:00","1991-01-01T00:00:00","1991-02-01T00:00:00","1991-03-01T00:00:00","1991-04-01T00:00:00","1991-05-01T00:00:00","1991-06-01T00:00:00","1991-07-01T00:00:00","1991-08-01T00:00:00","1991-09-01T00:00:00","1991-10-01T00:00:00","1991-11-01T00:00:00","1991-12-01T00:00:00","1992-01-01T00:00:00","1992-02-01T00:00:00","1992-03-01T00:00:00","1992-04-01T00:00:00","1992-05-01T00:00:00","1992-06-01T00:00:00","1992-07-01T00:00:00","1992-08-01T00:00:00","1992-09-01T00:00:00","1992-10-01T00:00:00","1992-11-01T00:00:00","1992-12-01T00:00:00","1993-01-01T00:00:00","1993-02-01T00:00:00","1993-03-01T00:00:00","1993-04-01T00:00:00","1993-05-01T00:00:00","1993-06-01T00:00:00","1993-07-01T00:00:00","1993-08-01T00:00:00","1993-09-01T00:00:00","1993-10-01T00:00:00","1993-11-01T00:00:00","1993-12-01T00:00:00","1994-01-01T00:00:00","1994-02-01T00:00:00","1994-03-01T00:00:00","1994-04-01T00:00:00","1994-05-01T00:00:00","1994-06-01T00:00:00","1994-07-01T00:00:00","1994-08-01T00:00:00","1994-09-01T00:00:00","1994-10-01T00:00:00","1994-11-01T00:00:00","1994-12-01T00:00:00","1995-01-01T00:00:00","1995-02-01T00:00:00","1995-03-01T00:00:00","1995-04-01T00:00:00","1995-05-01T00:00:00","1995-06-01T00:00:00","1995-07-01T00:00:00","1995-08-01T00:00:00","1995-09-01T00:00:00","1995-10-01T00:00:00","1995-11-01T00:00:00","1995-12-01T00:00:00","1996-01-01T00:00:00","1996-02-01T00:00:00","1996-03-01T00:00:00","1996-04-01T00:00:00","1996-05-01T00:00:00","1996-06-01T00:00:00","1996-07-01T00:00:00","1996-08-01T00:00:00","1996-09-01T00:00:00","1996-10-01T00:00:00","1996-11-01T00:00:00","1996-12-01T00:00:00","1997-01-01T00:00:00","1997-02-01T00:00:00","1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00 ...

# %%
# Out:
# <div>                            <div id="8a19a7ea-fac9-4ce6-b2dd-b213a19ef0bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a19a7ea-fac9-4ce6-b2dd-b213a19ef0bd")) {                    Plotly.newPlot(                        "8a19a7ea-fac9-4ce6-b2dd-b213a19ef0bd",                        [{"hovertemplate":"year=2016<br>month=%{x}<br>AIR_New=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2016","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[11056.49152542373,9986.50847457627,16391,15829,14323,16569,13265,12061,12351,11613,11950,14622],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2017<br>month=%{x}<br>AIR_New=%{y}<extra></extra>","legendgroup":"2017","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2017","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[12879.186440677966,11632.813559322034,18875,19502,18706,19175,16654,14628,15254,13473,14601,15742],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2018<br>month=%{x}<br>AIR_New=%{y}<extra></extra>","legendgroup":"2018","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2018","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[14723.949152542373,13299.050847457627,20190,21432,21344,20798,17188,14753,16083,13568,15198,18320],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2019<br>month=%{x}<br>AIR_New=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[14651.440677966102,13233.559322033898,24069,23636,21912,21331,16861,14332,17839,13322,15455,20349],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>month=%{x}<br>AIR_New=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[8556.525423728814,7728.474576271186,19403,19159,19428,24903,18512,15330,17141,14489,17716,21525],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2021<br>month=%{x}<br>AIR_New=%{y}<extra></extra>","legendgroup":"2021","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2021","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[15449.559322033898,13954.440677966102,25916,24210,22058,21670,18018,14912,15081,14549,16628,19635],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0 ...

# %%
# Out:
# <div>                            <div id="8caf51fb-6776-46d7-b153-e441082e6ea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8caf51fb-6776-46d7-b153-e441082e6ea8")) {                    Plotly.newPlot(                        "8caf51fb-6776-46d7-b153-e441082e6ea8",                        [{"hovertemplate":"DATE=%{x}<br>WM_New=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1986-01-01T00:00:00","1986-02-01T00:00:00","1986-03-01T00:00:00","1986-04-01T00:00:00","1986-05-01T00:00:00","1986-06-01T00:00:00","1986-07-01T00:00:00","1986-08-01T00:00:00","1986-09-01T00:00:00","1986-10-01T00:00:00","1986-11-01T00:00:00","1986-12-01T00:00:00","1987-01-01T00:00:00","1987-02-01T00:00:00","1987-03-01T00:00:00","1987-04-01T00:00:00","1987-05-01T00:00:00","1987-06-01T00:00:00","1987-07-01T00:00:00","1987-08-01T00:00:00","1987-09-01T00:00:00","1987-10-01T00:00:00","1987-11-01T00:00:00","1987-12-01T00:00:00","1988-01-01T00:00:00","1988-02-01T00:00:00","1988-03-01T00:00:00","1988-04-01T00:00:00","1988-05-01T00:00:00","1988-06-01T00:00:00","1988-07-01T00:00:00","1988-08-01T00:00:00","1988-09-01T00:00:00","1988-10-01T00:00:00","1988-11-01T00:00:00","1988-12-01T00:00:00","1989-01-01T00:00:00","1989-02-01T00:00:00","1989-03-01T00:00:00","1989-04-01T00:00:00","1989-05-01T00:00:00","1989-06-01T00:00:00","1989-07-01T00:00:00","1989-08-01T00:00:00","1989-09-01T00:00:00","1989-10-01T00:00:00","1989-11-01T00:00:00","1989-12-01T00:00:00","1990-01-01T00:00:00","1990-02-01T00:00:00","1990-03-01T00:00:00","1990-04-01T00:00:00","1990-05-01T00:00:00","1990-06-01T00:00:00","1990-07-01T00:00:00","1990-08-01T00:00:00","1990-09-01T00:00:00","1990-10-01T00:00:00","1990-11-01T00:00:00","1990-12-01T00:00:00","1991-01-01T00:00:00","1991-02-01T00:00:00","1991-03-01T00:00:00","1991-04-01T00:00:00","1991-05-01T00:00:00","1991-06-01T00:00:00","1991-07-01T00:00:00","1991-08-01T00:00:00","1991-09-01T00:00:00","1991-10-01T00:00:00","1991-11-01T00:00:00","1991-12-01T00:00:00","1992-01-01T00:00:00","1992-02-01T00:00:00","1992-03-01T00:00:00","1992-04-01T00:00:00","1992-05-01T00:00:00","1992-06-01T00:00:00","1992-07-01T00:00:00","1992-08-01T00:00:00","1992-09-01T00:00:00","1992-10-01T00:00:00","1992-11-01T00:00:00","1992-12-01T00:00:00","1993-01-01T00:00:00","1993-02-01T00:00:00","1993-03-01T00:00:00","1993-04-01T00:00:00","1993-05-01T00:00:00","1993-06-01T00:00:00","1993-07-01T00:00:00","1993-08-01T00:00:00","1993-09-01T00:00:00","1993-10-01T00:00:00","1993-11-01T00:00:00","1993-12-01T00:00:00","1994-01-01T00:00:00","1994-02-01T00:00:00","1994-03-01T00:00:00","1994-04-01T00:00:00","1994-05-01T00:00:00","1994-06-01T00:00:00","1994-07-01T00:00:00","1994-08-01T00:00:00","1994-09-01T00:00:00","1994-10-01T00:00:00","1994-11-01T00:00:00","1994-12-01T00:00:00","1995-01-01T00:00:00","1995-02-01T00:00:00","1995-03-01T00:00:00","1995-04-01T00:00:00","1995-05-01T00:00:00","1995-06-01T00:00:00","1995-07-01T00:00:00","1995-08-01T00:00:00","1995-09-01T00:00:00","1995-10-01T00:00:00","1995-11-01T00:00:00","1995-12-01T00:00:00","1996-01-01T00:00:00","1996-02-01T00:00:00","1996-03-01T00:00:00","1996-04-01T00:00:00","1996-05-01T00:00:00","1996-06-01T00:00:00","1996-07-01T00:00:00","1996-08-01T00:00:00","1996-09-01T00:00:00","1996-10-01T00:00:00","1996-11-01T00:00:00","1996-12-01T00:00:00","1997-01-01T00:00:00","1997-02-01T00:00:00","1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00" ...

# %%
# Out:
# <div>                            <div id="8e9791a7-83d9-4a5b-9f17-f6e5a4b94430" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e9791a7-83d9-4a5b-9f17-f6e5a4b94430")) {                    Plotly.newPlot(                        "8e9791a7-83d9-4a5b-9f17-f6e5a4b94430",                        [{"hovertemplate":"year=2016<br>month=%{x}<br>WM_New=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2016","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[5882.118644067797,5312.881355932203,7270,6071,5854,6394,5840,6276,6706,6336,7618,7175],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2017<br>month=%{x}<br>WM_New=%{y}<extra></extra>","legendgroup":"2017","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2017","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[6154.813559322034,5559.186440677966,7543,6274,5867,6351,5980,6304,7187,6583,6827,7136],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2018<br>month=%{x}<br>WM_New=%{y}<extra></extra>","legendgroup":"2018","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2018","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[5782.813559322034,5223.186440677966,6582,6183,5624,5385,5324,6415,6521,6620,6356,6963],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2019<br>month=%{x}<br>WM_New=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[5705.576271186441,5153.423728813559,6611,6468,6806,6502,4915,6782,7205,7615,7209,7265],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>month=%{x}<br>WM_New=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[4075.7118644067796,3681.2881355932204,6400,5557,6083,6555,6862,7492,7992,8406,8566,8064],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2021<br>month=%{x}<br>WM_New=%{y}<extra></extra>","legendgroup":"2021","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2021","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[6901.440677966101,6233.559322033899,8312,7720,7032,6640,6238,6738,6995,7668,8438,7856],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0. ...

# %%
# Out:
# <div>                            <div id="e92097cf-7d51-4bfc-8d6b-7851823ee37b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e92097cf-7d51-4bfc-8d6b-7851823ee37b")) {                    Plotly.newPlot(                        "e92097cf-7d51-4bfc-8d6b-7851823ee37b",                        [{"hovertemplate":"DATE=%{x}<br>RF_New=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1986-01-01T00:00:00","1986-02-01T00:00:00","1986-03-01T00:00:00","1986-04-01T00:00:00","1986-05-01T00:00:00","1986-06-01T00:00:00","1986-07-01T00:00:00","1986-08-01T00:00:00","1986-09-01T00:00:00","1986-10-01T00:00:00","1986-11-01T00:00:00","1986-12-01T00:00:00","1987-01-01T00:00:00","1987-02-01T00:00:00","1987-03-01T00:00:00","1987-04-01T00:00:00","1987-05-01T00:00:00","1987-06-01T00:00:00","1987-07-01T00:00:00","1987-08-01T00:00:00","1987-09-01T00:00:00","1987-10-01T00:00:00","1987-11-01T00:00:00","1987-12-01T00:00:00","1988-01-01T00:00:00","1988-02-01T00:00:00","1988-03-01T00:00:00","1988-04-01T00:00:00","1988-05-01T00:00:00","1988-06-01T00:00:00","1988-07-01T00:00:00","1988-08-01T00:00:00","1988-09-01T00:00:00","1988-10-01T00:00:00","1988-11-01T00:00:00","1988-12-01T00:00:00","1989-01-01T00:00:00","1989-02-01T00:00:00","1989-03-01T00:00:00","1989-04-01T00:00:00","1989-05-01T00:00:00","1989-06-01T00:00:00","1989-07-01T00:00:00","1989-08-01T00:00:00","1989-09-01T00:00:00","1989-10-01T00:00:00","1989-11-01T00:00:00","1989-12-01T00:00:00","1990-01-01T00:00:00","1990-02-01T00:00:00","1990-03-01T00:00:00","1990-04-01T00:00:00","1990-05-01T00:00:00","1990-06-01T00:00:00","1990-07-01T00:00:00","1990-08-01T00:00:00","1990-09-01T00:00:00","1990-10-01T00:00:00","1990-11-01T00:00:00","1990-12-01T00:00:00","1991-01-01T00:00:00","1991-02-01T00:00:00","1991-03-01T00:00:00","1991-04-01T00:00:00","1991-05-01T00:00:00","1991-06-01T00:00:00","1991-07-01T00:00:00","1991-08-01T00:00:00","1991-09-01T00:00:00","1991-10-01T00:00:00","1991-11-01T00:00:00","1991-12-01T00:00:00","1992-01-01T00:00:00","1992-02-01T00:00:00","1992-03-01T00:00:00","1992-04-01T00:00:00","1992-05-01T00:00:00","1992-06-01T00:00:00","1992-07-01T00:00:00","1992-08-01T00:00:00","1992-09-01T00:00:00","1992-10-01T00:00:00","1992-11-01T00:00:00","1992-12-01T00:00:00","1993-01-01T00:00:00","1993-02-01T00:00:00","1993-03-01T00:00:00","1993-04-01T00:00:00","1993-05-01T00:00:00","1993-06-01T00:00:00","1993-07-01T00:00:00","1993-08-01T00:00:00","1993-09-01T00:00:00","1993-10-01T00:00:00","1993-11-01T00:00:00","1993-12-01T00:00:00","1994-01-01T00:00:00","1994-02-01T00:00:00","1994-03-01T00:00:00","1994-04-01T00:00:00","1994-05-01T00:00:00","1994-06-01T00:00:00","1994-07-01T00:00:00","1994-08-01T00:00:00","1994-09-01T00:00:00","1994-10-01T00:00:00","1994-11-01T00:00:00","1994-12-01T00:00:00","1995-01-01T00:00:00","1995-02-01T00:00:00","1995-03-01T00:00:00","1995-04-01T00:00:00","1995-05-01T00:00:00","1995-06-01T00:00:00","1995-07-01T00:00:00","1995-08-01T00:00:00","1995-09-01T00:00:00","1995-10-01T00:00:00","1995-11-01T00:00:00","1995-12-01T00:00:00","1996-01-01T00:00:00","1996-02-01T00:00:00","1996-03-01T00:00:00","1996-04-01T00:00:00","1996-05-01T00:00:00","1996-06-01T00:00:00","1996-07-01T00:00:00","1996-08-01T00:00:00","1996-09-01T00:00:00","1996-10-01T00:00:00","1996-11-01T00:00:00","1996-12-01T00:00:00","1997-01-01T00:00:00","1997-02-01T00:00:00","1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00" ...

# %%
# Out:
# <div>                            <div id="074edbc1-4b50-40a9-9b52-4f6a1f1dd402" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("074edbc1-4b50-40a9-9b52-4f6a1f1dd402")) {                    Plotly.newPlot(                        "074edbc1-4b50-40a9-9b52-4f6a1f1dd402",                        [{"hovertemplate":"year=2016<br>month=%{x}<br>RF_New=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2016","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[6224.6949152542375,5622.3050847457625,8671,8733,8552,9017,7949,7543,8045,7429,7697,7115],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2017<br>month=%{x}<br>RF_New=%{y}<extra></extra>","legendgroup":"2017","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2017","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[7061.6949152542375,6378.3050847457625,9241,8344,8485,8713,8511,8580,8466,8132,7822,6604],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2018<br>month=%{x}<br>RF_New=%{y}<extra></extra>","legendgroup":"2018","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2018","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[6215.237288135593,5613.762711864407,7260,7526,7578,7130,6516,6935,7210,6854,7070,6188],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2019<br>month=%{x}<br>RF_New=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[5774.406779661017,5215.593220338983,7357,7712,7778,7461,7342,7017,7367,7046,7222,6902],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>month=%{x}<br>RF_New=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[3504.576271186441,3165.423728813559,7266,7015,7767,8874,9147,9085,9358,8796,8989,7964],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2021<br>month=%{x}<br>RF_New=%{y}<extra></extra>","legendgroup":"2021","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2021","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[6361.3050847457625,5745.6949152542375,9466,7729,7487,7425,7410,7364,7638,7636,8085,7578],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"] ...

# %%
# Out:
# <div>                            <div id="2c687e41-94c1-4959-aac1-400e62c50aa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c687e41-94c1-4959-aac1-400e62c50aa8")) {                    Plotly.newPlot(                        "2c687e41-94c1-4959-aac1-400e62c50aa8",                        [{"hovertemplate":"DATE=%{x}<br>TV_New=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1986-01-01T00:00:00","1986-02-01T00:00:00","1986-03-01T00:00:00","1986-04-01T00:00:00","1986-05-01T00:00:00","1986-06-01T00:00:00","1986-07-01T00:00:00","1986-08-01T00:00:00","1986-09-01T00:00:00","1986-10-01T00:00:00","1986-11-01T00:00:00","1986-12-01T00:00:00","1987-01-01T00:00:00","1987-02-01T00:00:00","1987-03-01T00:00:00","1987-04-01T00:00:00","1987-05-01T00:00:00","1987-06-01T00:00:00","1987-07-01T00:00:00","1987-08-01T00:00:00","1987-09-01T00:00:00","1987-10-01T00:00:00","1987-11-01T00:00:00","1987-12-01T00:00:00","1988-01-01T00:00:00","1988-02-01T00:00:00","1988-03-01T00:00:00","1988-04-01T00:00:00","1988-05-01T00:00:00","1988-06-01T00:00:00","1988-07-01T00:00:00","1988-08-01T00:00:00","1988-09-01T00:00:00","1988-10-01T00:00:00","1988-11-01T00:00:00","1988-12-01T00:00:00","1989-01-01T00:00:00","1989-02-01T00:00:00","1989-03-01T00:00:00","1989-04-01T00:00:00","1989-05-01T00:00:00","1989-06-01T00:00:00","1989-07-01T00:00:00","1989-08-01T00:00:00","1989-09-01T00:00:00","1989-10-01T00:00:00","1989-11-01T00:00:00","1989-12-01T00:00:00","1990-01-01T00:00:00","1990-02-01T00:00:00","1990-03-01T00:00:00","1990-04-01T00:00:00","1990-05-01T00:00:00","1990-06-01T00:00:00","1990-07-01T00:00:00","1990-08-01T00:00:00","1990-09-01T00:00:00","1990-10-01T00:00:00","1990-11-01T00:00:00","1990-12-01T00:00:00","1991-01-01T00:00:00","1991-02-01T00:00:00","1991-03-01T00:00:00","1991-04-01T00:00:00","1991-05-01T00:00:00","1991-06-01T00:00:00","1991-07-01T00:00:00","1991-08-01T00:00:00","1991-09-01T00:00:00","1991-10-01T00:00:00","1991-11-01T00:00:00","1991-12-01T00:00:00","1992-01-01T00:00:00","1992-02-01T00:00:00","1992-03-01T00:00:00","1992-04-01T00:00:00","1992-05-01T00:00:00","1992-06-01T00:00:00","1992-07-01T00:00:00","1992-08-01T00:00:00","1992-09-01T00:00:00","1992-10-01T00:00:00","1992-11-01T00:00:00","1992-12-01T00:00:00","1993-01-01T00:00:00","1993-02-01T00:00:00","1993-03-01T00:00:00","1993-04-01T00:00:00","1993-05-01T00:00:00","1993-06-01T00:00:00","1993-07-01T00:00:00","1993-08-01T00:00:00","1993-09-01T00:00:00","1993-10-01T00:00:00","1993-11-01T00:00:00","1993-12-01T00:00:00","1994-01-01T00:00:00","1994-02-01T00:00:00","1994-03-01T00:00:00","1994-04-01T00:00:00","1994-05-01T00:00:00","1994-06-01T00:00:00","1994-07-01T00:00:00","1994-08-01T00:00:00","1994-09-01T00:00:00","1994-10-01T00:00:00","1994-11-01T00:00:00","1994-12-01T00:00:00","1995-01-01T00:00:00","1995-02-01T00:00:00","1995-03-01T00:00:00","1995-04-01T00:00:00","1995-05-01T00:00:00","1995-06-01T00:00:00","1995-07-01T00:00:00","1995-08-01T00:00:00","1995-09-01T00:00:00","1995-10-01T00:00:00","1995-11-01T00:00:00","1995-12-01T00:00:00","1996-01-01T00:00:00","1996-02-01T00:00:00","1996-03-01T00:00:00","1996-04-01T00:00:00","1996-05-01T00:00:00","1996-06-01T00:00:00","1996-07-01T00:00:00","1996-08-01T00:00:00","1996-09-01T00:00:00","1996-10-01T00:00:00","1996-11-01T00:00:00","1996-12-01T00:00:00","1997-01-01T00:00:00","1997-02-01T00:00:00","1997-03-01T00:00:00","1997-04-01T00:00:00","1997-05-01T00:00:00","1997-06-01T00:00:00","1997-07-01T00:00:00","1997-08-01T00:00:00","1997-09-01T00:00:00","1997-10-01T00:00:00","1997-11-01T00:00:00","1997-12-01T00:00:00","1998-01-01T00:00:00","1998-02-01T00:00:00","1998-03-01T00:00:00","1998-04-01T00:00:00" ...

# %%
# Out:
# <div>                            <div id="10384846-5f2d-43fe-bb35-91fbbdedbbf6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10384846-5f2d-43fe-bb35-91fbbdedbbf6")) {                    Plotly.newPlot(                        "10384846-5f2d-43fe-bb35-91fbbdedbbf6",                        [{"hovertemplate":"year=2016<br>month=%{x}<br>TV_New=%{y}<extra></extra>","legendgroup":"2016","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2016","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[11822.033898305084,10677.966101694916,15790,14234,12723,13498,12940,15857,17030,15617,16427,17513],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2017<br>month=%{x}<br>TV_New=%{y}<extra></extra>","legendgroup":"2017","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2017","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[11193.101694915254,10109.898305084746,14651,12739,12011,13112,12735,15457,17567,17490,18003,18819],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2018<br>month=%{x}<br>TV_New=%{y}<extra></extra>","legendgroup":"2018","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2018","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[14273.135593220339,12891.864406779661,17037,15849,15558,14153,15185,18838,20338,20783,20261,21121],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2019<br>month=%{x}<br>TV_New=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[14850.57627118644,13413.42372881356,17285,16886,15832,14048,13566,16678,19522,19968,19771,20086],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>month=%{x}<br>TV_New=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[10344.016949152543,9342.983050847457,18184,14780,15099,16101,17541,19328,20574,19602,19622,18441],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2021<br>month=%{x}<br>TV_New=%{y}<extra></extra>","legendgroup":"2021","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2021","orientation":"v","showlegend":true,"x":["01","02","03","04","05","06","07","08","09","10","11","12"],"xaxis":"x","y":[13546.474576271186,12235.525423728814,18240,15142,14429,13965,13387,15694,17482,17592,17658,18884],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...
