# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df_ha = pd.read_excel('# 중국 매크로 데이터.xlsx', sheet_name = '백색')

# %%
df_ha = df_ha.iloc[23:]
df_ha = df_ha.iloc[:, 0:7]
display(df_ha)
# Out:
#     데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요  \
# 23                                 1986-01-01 00:00:00
# 24                                 1986-02-01 00:00:00
# 25                                 1986-03-01 00:00:00
# 26                                 1986-04-01 00:00:00
# 27                                 1986-05-01 00:00:00
# ..                                                 ...
# 443                                2021-08-01 00:00:00
# 444                                2021-09-01 00:00:00
# 445                                2021-10-01 00:00:00
# 446                                2021-11-01 00:00:00
# 447                                2021-12-01 00:00:00
#
#     CN: Industrial Production: Air Conditioner  \
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# ..                                         ...
# 443                                      14912
# 444                                      15081
# 445                                      14549
# 446                                      16628
# 447                                      19635
#
#     CN: Industrial Production: ytd: Air Conditioner  \
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# ..                                              ...
# 443                                          152198
# 444                                          166590
# 445                                          180924
# 446                                          197414
# 447                                          218357
#
#     CN: Industrial Production: Household Washing Machine  \
# 23                                               763.2
# 24                                               587.3
# 25                                                 774
# 26                                               717.7
# 27                                               772.6
# ..                                                 ...
# 443                                               6738
# 444                                               6995
# 445                                               7668
# 446                                               8438
# 447                                               7856
#
#     CN: Industrial Production: ytd: Household Washing Machine  \
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# ..                                                 ...
# 443                                              55915
# 444                                              62829
# 445                                              69685
# 446                                              78330
# 447                                              86185
#
#     CN: Industrial Production: Household Refrigerator  \
# 23                                              136.7
# 24                                              114.3
# 25                                              148.5
# 26                                                144
# 27                                                149
# ..                                                ...
# 443                                              7364
# 444                                              7638
# 445                                              7636
# 446                                              8085
# 447                                              7578
#
#     CN: Industrial Production: ytd: Household Refrigerator
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# ..                                                 ...
# 443                                              59135
# 444                                              66201
# 445                                              74122
# 446                                              82533
# 447                                              89921
#
# [425 rows x 7 columns]

# %%
df_ha = df_ha.rename(columns = {'데이터를 업데이트하고 계열을 추가하거나 지우려면 이 링크를 선택하시고 다운로드 새로고침/편집을 클릭하세요': 'DATE'})
df_ha = df_ha.rename(columns = {'CN: Industrial Production: Air Conditioner': 'AIR'})
df_ha = df_ha.rename(columns = {'CN: Industrial Production: ytd: Air Conditioner': 'AIR_YTD'})
df_ha = df_ha.rename(columns = {'CN: Industrial Production: Household Washing Machine': 'WM'})
df_ha = df_ha.rename(columns = {'CN: Industrial Production: ytd: Household Washing Machine': 'WM_YTD'})
df_ha = df_ha.rename(columns = {'CN: Industrial Production: Household Refrigerator': 'RF'})
df_ha = df_ha.rename(columns = {'CN: Industrial Production: ytd: Household Refrigerator': 'RF_YTD'})
df_ha.head(13)
# Out:
#                    DATE  AIR AIR_YTD     WM WM_YTD     RF RF_YTD
# 23  1986-01-01 00:00:00  NaN     NaN  763.2    NaN  136.7    NaN
# 24  1986-02-01 00:00:00  NaN     NaN  587.3    NaN  114.3    NaN
# 25  1986-03-01 00:00:00  NaN     NaN    774    NaN  148.5    NaN
# 26  1986-04-01 00:00:00  NaN     NaN  717.7    NaN    144    NaN
# 27  1986-05-01 00:00:00  NaN     NaN  772.6    NaN    149    NaN
# 28  1986-06-01 00:00:00  NaN     NaN  764.1    NaN  170.3    NaN
# 29  1986-07-01 00:00:00  NaN     NaN  711.3    NaN  195.4    NaN
# 30  1986-08-01 00:00:00  NaN     NaN  723.4    NaN  200.7    NaN
# 31  1986-09-01 00:00:00  NaN     NaN  719.9    NaN  204.3    NaN
# 32  1986-10-01 00:00:00  NaN     NaN  780.8    NaN  232.9    NaN
# 33  1986-11-01 00:00:00  NaN     NaN  845.6    NaN  267.1    NaN
# 34  1986-12-01 00:00:00  NaN     NaN  866.8    NaN  256.7    NaN
# 35  1987-01-01 00:00:00  NaN     NaN  788.9    NaN  226.8    NaN

# %%
df_ha['AIR_New'] = np.where(pd.notnull(df_ha['AIR']) == True, df_ha['AIR'], df_ha['AIR_YTD'])
df_ha['WM_New'] = np.where(pd.notnull(df_ha['WM']) == True, df_ha['WM'], df_ha['WM_YTD'])
df_ha['RF_New'] = np.where(pd.notnull(df_ha['RF']) == True, df_ha['RF'], df_ha['RF_YTD'])
df_ha.tail(13)
# Out:
#                     DATE    AIR AIR_YTD    WM     WM_YTD    RF     RF_YTD  \
# 435  2020-11-01 00:00:00  17716  189292  8566      72285  8989      82605
# 436  2020-12-01 00:00:00  21525  210353  8064  80418.696  7964  90147.075
# 437  2021-02-01 00:00:00    NaN   29404   NaN      13135   NaN      12107
# 438  2021-03-01 00:00:00  25916   55953  8312      21447  9466      21578
# 439  2021-04-01 00:00:00  24210   79396  7720      29167  7729      29449
# 440  2021-05-01 00:00:00  22058  101759  7032      36184  7487      37116
# 441  2021-06-01 00:00:00  21670  123283  6640      42939  7425      44346
# 442  2021-07-01 00:00:00  18018  137686  6238      49177  7410      51773
# 443  2021-08-01 00:00:00  14912  152198  6738      55915  7364      59135
# 444  2021-09-01 00:00:00  15081  166590  6995      62829  7638      66201
# 445  2021-10-01 00:00:00  14549  180924  7668      69685  7636      74122
# 446  2021-11-01 00:00:00  16628  197414  8438      78330  8085      82533
# 447  2021-12-01 00:00:00  19635  218357  7856      86185  7578      89921
#
#     AIR_New WM_New RF_New
# 435   17716   8566   8989
# 436   21525   8064   7964
# 437   29404  13135  12107
# 438   25916   8312   9466
# 439   24210   7720   7729
# 440   22058   7032   7487
# 441   21670   6640   7425
# 442   18018   6238   7410
# 443   14912   6738   7364
# 444   15081   6995   7638
# 445   14549   7668   7636
# 446   16628   8438   8085
# 447   19635   7856   7578

# %%
df_ha = df_ha[['DATE','AIR_New', "WM_New", "RF_New"]]
df_ha.tail()
# Out:
#                     DATE AIR_New WM_New RF_New
# 443  2021-08-01 00:00:00   14912   6738   7364
# 444  2021-09-01 00:00:00   15081   6995   7638
# 445  2021-10-01 00:00:00   14549   7668   7636
# 446  2021-11-01 00:00:00   16628   8438   8085
# 447  2021-12-01 00:00:00   19635   7856   7578

# %%
fig = px.line(df_ha, x= 'DATE', y='AIR_New', title='Production of Air Conditioner in China')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=6, label="5y", step="year", stepmode="backward"),
            dict(count=11, label="10y", step="year", stepmode="backward"),
            #dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(step="all")
        ])
    )
)
fig.show()

# %%
fig = px.line(df_ha, x='DATE', y='WM_New', title='Production of Washing Machine in China')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=6, label="5y", step="year", stepmode="backward"),
            dict(count=11, label="10y", step="year", stepmode="backward"),
            #dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(step="all")
        ])
    )
)
fig.show()

# %%
fig = px.line(df_ha, x='DATE', y='RF_New', title='Production of Refrigerator in China')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=6, label="5y", step="year", stepmode="backward"),
            dict(count=11, label="10y", step="year", stepmode="backward"),
            #dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(step="all")
        ])
    )
)
fig.show()

# %%
df_ha = df_ha.set_index("DATE")
df_ha.head()
# Out:
#            AIR_New WM_New RF_New
# DATE
# 1986-01-01     NaN  763.2  136.7
# 1986-02-01     NaN  587.3  114.3
# 1986-03-01     NaN    774  148.5
# 1986-04-01     NaN  717.7    144
# 1986-05-01     NaN  772.6    149

# %%
index = pd.date_range("2016-01-01", "2022-01-01", freq="YS")
index
# Out:
# DatetimeIndex(['2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01',
#                '2020-01-01', '2021-01-01', '2022-01-01'],
#               dtype='datetime64[ns]', freq='AS-JAN')

# %%
empty = pd.DataFrame(index=index, columns=["data"])
empty
# Out:
#            data
# 2016-01-01  NaN
# 2017-01-01  NaN
# 2018-01-01  NaN
# 2019-01-01  NaN
# 2020-01-01  NaN
# 2021-01-01  NaN
# 2022-01-01  NaN

# %%
new_data = pd.concat([df_ha, empty], axis = 1, sort = False)
new_data.tail(30)
# Out:
#            AIR_New WM_New RF_New data
# 2019-08-01   14332   6782   7017  NaN
# 2019-09-01   17839   7205   7367  NaN
# 2019-10-01   13322   7615   7046  NaN
# 2019-11-01   15455   7209   7222  NaN
# 2019-12-01   20349   7265   6902  NaN
# 2020-01-01     NaN    NaN    NaN  NaN
# 2020-02-01   16285   7757   6670  NaN
# 2020-03-01   19403   6400   7266  NaN
# 2020-04-01   19159   5557   7015  NaN
# 2020-05-01   19428   6083   7767  NaN
# 2020-06-01   24903   6555   8874  NaN
# 2020-07-01   18512   6862   9147  NaN
# 2020-08-01   15330   7492   9085  NaN
# 2020-09-01   17141   7992   9358  NaN
# 2020-10-01   14489   8406   8796  NaN
# 2020-11-01   17716   8566   8989  NaN
# 2020-12-01   21525   8064   7964  NaN
# 2021-01-01     NaN    NaN    NaN  NaN
# 2021-02-01   29404  13135  12107  NaN
# 2021-03-01   25916   8312   9466  NaN
# 2021-04-01   24210   7720   7729  NaN
# 2021-05-01   22058   7032   7487  NaN
# 2021-06-01   21670   6640   7425  NaN
# 2021-07-01   18018   6238   7410  NaN
# 2021-08-01   14912   6738   7364  NaN
# 2021-09-01   15081   6995   7638  NaN
# 2021-10-01   14549   7668   7636  NaN
# 2021-11-01   16628   8438   8085  NaN
# 2021-12-01   19635   7856   7578  NaN
# 2022-01-01     NaN    NaN    NaN  NaN

# %%
new_data = df_ha.append(empty).sort_index()

for year in range(2016,2022):
    tmp = new_data.copy().loc[str(year)]
    jan_idx = tmp[:2].index[0]
    jan_val= (tmp[:2].values[-1]*31) / (31+28)
    tmp.loc[jan_idx] = jan_val
    
    feb_idx = tmp[:2].index[-1]
    feb_val = (tmp[:2].values[-1]*28) / (31+28)
    tmp.loc[feb_idx] = feb_val
    
    if "new_tmp" not in locals(): new_tmp = tmp
    else: new_tmp = new_tmp.append(tmp)

# %%
new_tmp.index.name = "DATE"
new_tmp
# Out:
#                  AIR_New       WM_New       RF_New data
# DATE
# 2016-01-01  11056.491525  5882.118644  6224.694915  NaN
# 2016-02-01   9986.508475  5312.881356  5622.305085  NaN
# 2016-03-01         16391         7270         8671  NaN
# 2016-04-01         15829         6071         8733  NaN
# 2016-05-01         14323         5854         8552  NaN
# ...                  ...          ...          ...  ...
# 2021-08-01         14912         6738         7364  NaN
# 2021-09-01         15081         6995         7638  NaN
# 2021-10-01         14549         7668         7636  NaN
# 2021-11-01         16628         8438         8085  NaN
# 2021-12-01         19635         7856         7578  NaN
#
# [72 rows x 4 columns]

# %%
new_tmp.reset_index(drop=False)
# Out:
#          DATE       AIR_New       WM_New       RF_New data
# 0  2016-01-01  11056.491525  5882.118644  6224.694915  NaN
# 1  2016-02-01   9986.508475  5312.881356  5622.305085  NaN
# 2  2016-03-01         16391         7270         8671  NaN
# 3  2016-04-01         15829         6071         8733  NaN
# 4  2016-05-01         14323         5854         8552  NaN
# ..        ...           ...          ...          ...  ...
# 67 2021-08-01         14912         6738         7364  NaN
# 68 2021-09-01         15081         6995         7638  NaN
# 69 2021-10-01         14549         7668         7636  NaN
# 70 2021-11-01         16628         8438         8085  NaN
# 71 2021-12-01         19635         7856         7578  NaN
#
# [72 rows x 5 columns]

# %%
del new_tmp['data']
new_tmp.head()
# Out:
#                  AIR_New       WM_New       RF_New
# DATE
# 2016-01-01  11056.491525  5882.118644  6224.694915
# 2016-02-01   9986.508475  5312.881356  5622.305085
# 2016-03-01         16391         7270         8671
# 2016-04-01         15829         6071         8733
# 2016-05-01         14323         5854         8552

# %%
new_tmp.reset_index(inplace = True)

new_tmp['year'] = [d.year for d in new_tmp.DATE]
##df_ha['month'] = [d.strftime('%b') for d in df_ha.DATE]
new_tmp['month'] = new_tmp['DATE'].dt.strftime('%m')
years = new_tmp['year'].unique()
new_tmp.tail(13)
# Out:
#          DATE       AIR_New       WM_New       RF_New  year month
# 59 2020-12-01         21525         8064         7964  2020    12
# 60 2021-01-01  15449.559322  6901.440678  6361.305085  2021    01
# 61 2021-02-01  13954.440678  6233.559322  5745.694915  2021    02
# 62 2021-03-01         25916         8312         9466  2021    03
# 63 2021-04-01         24210         7720         7729  2021    04
# 64 2021-05-01         22058         7032         7487  2021    05
# 65 2021-06-01         21670         6640         7425  2021    06
# 66 2021-07-01         18018         6238         7410  2021    07
# 67 2021-08-01         14912         6738         7364  2021    08
# 68 2021-09-01         15081         6995         7638  2021    09
# 69 2021-10-01         14549         7668         7636  2021    10
# 70 2021-11-01         16628         8438         8085  2021    11
# 71 2021-12-01         19635         7856         7578  2021    12

# %%
fig = px.line(new_tmp, x='month', y='AIR_New', color='year')
fig.show()

# %%
fig = px.line(new_tmp, x='month', y='WM_New', color='year')
fig.show()

# %%
fig = px.line(new_tmp, x='month', y='RF_New', color='year')
fig.show()

# %%
df_ha_air = new_tmp.pivot_table('AIR_New', 'year','month', aggfunc=np.sum)
df_ha_air
# Out:
# month            01            02       03       04       05       06  \
# year
# 2016   11056.491525   9986.508475  16391.0  15829.0  14323.0  16569.0
# 2017   12879.186441  11632.813559  18875.0  19502.0  18706.0  19175.0
# 2018   14723.949153  13299.050847  20190.0  21432.0  21344.0  20798.0
# 2019   14651.440678  13233.559322  24069.0  23636.0  21912.0  21331.0
# 2020    8556.525424   7728.474576  19403.0  19159.0  19428.0  24903.0
# 2021   15449.559322  13954.440678  25916.0  24210.0  22058.0  21670.0
#
# month       07       08       09       10       11       12
# year
# 2016   13265.0  12061.0  12351.0  11613.0  11950.0  14622.0
# 2017   16654.0  14628.0  15254.0  13473.0  14601.0  15742.0
# 2018   17188.0  14753.0  16083.0  13568.0  15198.0  18320.0
# 2019   16861.0  14332.0  17839.0  13322.0  15455.0  20349.0
# 2020   18512.0  15330.0  17141.0  14489.0  17716.0  21525.0
# 2021   18018.0  14912.0  15081.0  14549.0  16628.0  19635.0

# %%
df_ha_wm = new_tmp.pivot_table('WM_New', 'year','month', aggfunc=np.sum)
df_ha_wm
# Out:
# month           01           02      03      04      05      06      07  \
# year
# 2016   5882.118644  5312.881356  7270.0  6071.0  5854.0  6394.0  5840.0
# 2017   6154.813559  5559.186441  7543.0  6274.0  5867.0  6351.0  5980.0
# 2018   5782.813559  5223.186441  6582.0  6183.0  5624.0  5385.0  5324.0
# 2019   5705.576271  5153.423729  6611.0  6468.0  6806.0  6502.0  4915.0
# 2020   4075.711864  3681.288136  6400.0  5557.0  6083.0  6555.0  6862.0
# 2021   6901.440678  6233.559322  8312.0  7720.0  7032.0  6640.0  6238.0
#
# month      08      09      10      11      12
# year
# 2016   6276.0  6706.0  6336.0  7618.0  7175.0
# 2017   6304.0  7187.0  6583.0  6827.0  7136.0
# 2018   6415.0  6521.0  6620.0  6356.0  6963.0
# 2019   6782.0  7205.0  7615.0  7209.0  7265.0
# 2020   7492.0  7992.0  8406.0  8566.0  8064.0
# 2021   6738.0  6995.0  7668.0  8438.0  7856.0

# %%
df_ha_rf = new_tmp.pivot_table('RF_New', 'year','month', aggfunc=np.sum)
df_ha_rf
# Out:
# month           01           02      03      04      05      06      07  \
# year
# 2016   6224.694915  5622.305085  8671.0  8733.0  8552.0  9017.0  7949.0
# 2017   7061.694915  6378.305085  9241.0  8344.0  8485.0  8713.0  8511.0
# 2018   6215.237288  5613.762712  7260.0  7526.0  7578.0  7130.0  6516.0
# 2019   5774.406780  5215.593220  7357.0  7712.0  7778.0  7461.0  7342.0
# 2020   3504.576271  3165.423729  7266.0  7015.0  7767.0  8874.0  9147.0
# 2021   6361.305085  5745.694915  9466.0  7729.0  7487.0  7425.0  7410.0
#
# month      08      09      10      11      12
# year
# 2016   7543.0  8045.0  7429.0  7697.0  7115.0
# 2017   8580.0  8466.0  8132.0  7822.0  6604.0
# 2018   6935.0  7210.0  6854.0  7070.0  6188.0
# 2019   7017.0  7367.0  7046.0  7222.0  6902.0
# 2020   9085.0  9358.0  8796.0  8989.0  7964.0
# 2021   7364.0  7638.0  7636.0  8085.0  7578.0
